# %% [markdown]
# **Importing the libraries and loading the data**
#
# If imports are returning errors, run `%pip install [missing import]`

# %%
# %pip install pandas
# %pip install gdown
# %pip install numpy
# %pip install seaborn
# %pip install matplotlib
# %pip install gensim
# %pip install pyLDAvis
# %pip install nltk
# %pip install bs4
# %pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gdown in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from requests[socks]->gdown) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (1.24.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gensim) (1.24.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyLDAvis in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (3.4.0)
# Requirement already satisfied: numpy>=1.22.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (1.24.4)
# Requirement already satisfied: scipy in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (1.10.1)
# Requirement already satisfied: pandas>=1.3.4 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (2.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (2.8.6)
# Requirement already satisfied: funcy in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (1.3.2)
# Requirement already satisfied: gensim in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pyLDAvis) (4.3.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from pyLDAvis) (49.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas>=1.3.4->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas>=1.3.4->pyLDAvis) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from pandas>=1.3.4->pyLDAvis) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from gensim->pyLDAvis) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from jinja2->pyLDAvis) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.4->pyLDAvis) (1.15.0)
# Requirement already satisfied: wrapt in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from smart-open>=1.8.1->gensim->pyLDAvis) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (3.9.1)
# Requirement already satisfied: click in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from beautifulsoup4->bs4) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: pillow in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from wordcloud) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# some basic libraries
import pandas as pd
import os
import gdown
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import io

# some libraries useful for text pre-processing and text data exploration
import re, string
# %pip install pyLDAvis

# Import necessary libraries
import gensim
import pyLDAvis
import pyLDAvis.gensim_models
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from bs4 import BeautifulSoup
from wordcloud import WordCloud

# some libraries for for model-building and evaluation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report

# some libraries for feature extraction from texts
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer #bag of words
from gensim.models import Word2Vec #word embedding
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jaelynliou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jaelynliou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
url = 'https://drive.google.com/file/d/1r5xDdeOsuwUDZy_1GVNf_hS8vxQ7LtEV/view?usp=share_link'

# Extract file ID from the URL
file_id = url.split('/')[-2]

# Construct the download URL
dwn_url = f'https://drive.google.com/uc?id={file_id}'

# Download the file
output = 'complaints.csv'

# Download only if file doesn't already exist
if not os.path.exists(output):
    gdown.download(dwn_url, output, quiet=False)
else:
    print("File already exists. Skipping download.")

# Read the downloaded CSV file into a DataFrame
data = pd.read_csv(output)

data.head()
# Out:
# File already exists. Skipping download.
#   Date received                                            Product  \
# 0    2022-12-25                        Credit card or prepaid card
# 1    2022-10-17                        Credit card or prepaid card
# 2    2023-01-10  Credit reporting, credit repair services, or o...
# 3    2022-12-31  Credit reporting, credit repair services, or o...
# 4    2022-12-29                        Credit card or prepaid card
#
#                     Sub-product                                 Issue  \
# 0                     Gift card              Unexpected or other fees
# 1             Store credit card                  Closing your account
# 2              Credit reporting  Incorrect information on your report
# 3              Credit reporting           Improper use of your report
# 4  General-purpose prepaid card              Unexpected or other fees
#
#                                            Sub-issue  \
# 0                                                NaN
# 1                           Can't close your account
# 2                Information belongs to someone else
# 3  Credit inquiries on your report that you don't...
# 4                                                NaN
#
#   Consumer complaint narrative  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                              Company public response  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Company has responded to the consumer and the ...
# 4                                                NaN
#
#                                Company State ZIP code Tags  \
# 0                 Incomm Holdings Inc.    NY  11576.0  NaN
# 1       Bread Financial Holdings, Inc.    PA  19610.0  NaN
# 2                        EQUIFAX, INC.    PA  19127.0  NaN
# 3  Experian Information Solutions Inc.    MO  63033.0  NaN
# 4             AMERICAN EXPRESS COMPANY    CA  90746.0  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           2022-12-25
# 1                        NaN           Web           2023-01-03
# 2                        NaN           Web           2023-01-10
# 3       Consent not provided           Web           2022-12-31
# 4                        NaN           Web           2022-12-29
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0                Untimely response               No                NaN
# 1          Closed with explanation              Yes                NaN
# 2                      In progress              Yes                NaN
# 3  Closed with non-monetary relief              Yes                NaN
# 4          Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       6358716
# 1       6096325
# 2       6413829
# 3       6382980
# 4       6375967

# %%
data['Company'].value_counts() # Counts the number of occurrences of each unique value in the 'Company' column
# Out:
# Company
# EQUIFAX, INC.                                    562111
# TRANSUNION INTERMEDIATE HOLDINGS, INC.           467190
# Experian Information Solutions Inc.              436041
# BANK OF AMERICA, NATIONAL ASSOCIATION            121461
# WELLS FARGO & COMPANY                            103010
#                                                   ...
# Commonwealth Auto Credit, LLC                         1
# REVERSE e MORTGAGE LLC Dba CrossPoint Funding         1
# Gregg & Gregg, P.C.                                   1
# Nationwide TFS, LLC                                   1
# BAY VALLEY                                            1
# Name: count, Length: 6611, dtype: int64

# %%
# Filters the dataset to only include rows where the 'Company' column is exactly 'CITIBANK, N.A.'
citigroup_data = data[data['Company'] == 'CITIBANK, N.A.']

# Displays the first 5 rows of the filtered DataFrame to preview the data
citigroup_data.head()
# Out:
#     Date received                                            Product  \
# 55     2022-12-30  Money transfer, virtual currency, or money ser...
# 75     2022-12-26                        Checking or savings account
# 80     2022-12-25                        Credit card or prepaid card
# 154    2022-12-28                        Credit card or prepaid card
# 234    2022-12-07  Credit reporting, credit repair services, or o...
#
#                                     Sub-product  \
# 55                 Domestic (US) money transfer
# 75                             Checking account
# 80   General-purpose credit card or charge card
# 154                           Store credit card
# 234                            Credit reporting
#
#                                                Issue  \
# 55                         Other transaction problem
# 75                                Closing an account
# 80   Problem with a purchase shown on your statement
# 154  Problem with a purchase shown on your statement
# 234                      Improper use of your report
#
#                                              Sub-issue  \
# 55                                                 NaN
# 75                            Can't close your account
# 80   Credit card company isn't resolving a dispute ...
# 154  Credit card company isn't resolving a dispute ...
# 234  Credit inquiries on your report that you don't...
#
#                           Consumer complaint narrative  \
# 55   A Wire transfer of {$23000.00} was initiated o...
# 75   My father passed away on XX/XX/2022. I informe...
# 80   Back in XXXX of 2021, I bought a XXXXXXXX XXXX...
# 154  I am a platinum card holder with Macys. I gene...
# 234  I disputed the unknown inquires and the compan...
#
#                                Company public response         Company State  \
# 55   Company has responded to the consumer and the ...  CITIBANK, N.A.    CA
# 75   Company has responded to the consumer and the ...  CITIBANK, N.A.    WA
# 80   Company has responded to the consumer and the ...  CITIBANK, N.A.    SC
# 154  Company has responded to the consumer and the ...  CITIBANK, N.A.    DC
# 234  Company has responded to the consumer and the ...  CITIBANK, N.A.    MD
#
#     ZIP code Tags Consumer consent provided? Submitted via  \
# 55   91730.0  NaN           Consent provided           Web
# 75   98102.0  NaN           Consent provided           Web
# 80   29072.0  NaN           Consent provided           Web
# 154  20012.0  NaN           Consent provided           Web
# 234  20743.0  NaN           Consent provided           Web
#
#     Date sent to company Company response to consumer Timely response?  \
# 55            2022-12-30      Closed with explanation              Yes
# 75            2022-12-26      Closed with explanation              Yes
# 80            2022-12-25  Closed with monetary relief              Yes
# 154           2022-12-28      Closed with explanation              Yes
# 234           2022-12-30      Closed with explanation              Yes
#
#     Consumer disputed?  Complaint ID
# 55                 NaN       6378719
# 75                 NaN       6361109
# 80                 NaN       6359652
# 154                NaN       6368493
# 234                NaN       6286123

# %%
# Counts the number of 'Yes' and 'No' (or other unique values) in the 'Timely response?' column of the Citibank data
x = citigroup_data['Timely response?'].value_counts()

# Prints the count of each response category (e.g., how many timely and untimely responses)
print(x)

# Creates a bar plot to visualize the count of timely responses
sns.barplot(x=x.index, y=x)  # x-axis: response categories ('Yes', 'No'), y-axis: their counts
# Out:
# Timely response?
# Yes    80158
# No       369
# Name: count, dtype: int64
# <Axes: xlabel='Timely response?', ylabel='count'>

# %%
# Counts how many times each unique value (e.g., 'Yes', 'No') appears in the 'Consumer disputed?' column
x = citigroup_data['Consumer disputed?'].value_counts()

# Prints the result — the number of disputed vs. non-disputed complaints
print(x)

# Plots a bar chart showing how often consumers disputed the complaint resolution
sns.barplot(x=x.index, y=x)  # x-axis: dispute categories ('Yes', 'No'), y-axis: number of cases
# Out:
# Consumer disputed?
# No     28071
# Yes     6697
# Name: count, dtype: int64
# <Axes: xlabel='Consumer disputed?', ylabel='count'>

# %%
# Count the number of occurrences of each product type in Citibank complaints
x = citigroup_data['Product'].value_counts()

# Print the frequency of each product to the console
print(x)

# Rotate x-axis labels by 45 degrees to avoid overlapping and align them to the right
plt.xticks(rotation=45, ha='right')

# Set a title for the bar chart
plt.title("Count of Different Products", color='black')

# Create a dictionary to rename long or grouped product labels for better readability
new_labels = {
    'Credit reporting, credit repair services, or other personal consumer reports': 'Credit Services',
    'Money transfer, virtual currency, or money service': 'Money Services',
    'Payday loan, title loan, or personal loan': 'Loan Services'
}

# Create a barplot using seaborn to show the count of each product
ax = sns.barplot(x=x.index, y=x)

# Get the current x-axis labels from the plot
current_labels = [item.get_text() for item in ax.get_xticklabels()]

# Replace long labels with simplified versions using the dictionary (if a match exists)
updated_labels = [new_labels.get(label, label) for label in current_labels]

# Apply the updated, shortened labels to the x-axis
ax.set_xticklabels(updated_labels)

# Plot another barplot with red color overlay
sns.barplot(x=x.index, y=x, color='red')  # This creates a second red barplot on top
# Out:
# Product
# Credit card or prepaid card                                                     22092
# Credit card                                                                     16817
# Mortgage                                                                        10249
# Checking or savings account                                                      8967
# Credit reporting, credit repair services, or other personal consumer reports     7868
# Debt collection                                                                  6859
# Bank account or service                                                          4450
# Money transfer, virtual currency, or money service                                844
# Consumer Loan                                                                     765
# Student loan                                                                      737
# Credit reporting                                                                  267
# Payday loan, title loan, or personal loan                                         214
# Prepaid card                                                                      206
# Money transfers                                                                   102
# Vehicle loan or lease                                                              34
# Other financial service                                                            34
# Payday loan                                                                        22
# Name: count, dtype: int64
# <Axes: title={'center': 'Count of Different Products'}, xlabel='Product', ylabel='count'>

# %%
# Count how many times each unique value appears in the 'Consumer consent provided?' column
x = citigroup_data['Consumer consent provided?'].value_counts()

# Print the result to see the exact counts (e.g., 'Yes', 'No', 'N/A')
print(x)

# Set the size of the figure to make the plot larger and more readable (15 inches wide, 8 inches tall)
plt.figure(figsize=(15, 8))

# Create a bar plot to visualize the distribution of consumer consent statuses
sns.barplot(x=x.index, y=x)  # x-axis: categories of consent, y-axis: their counts
# Out:
# Consumer consent provided?
# Consent provided        29628
# Consent not provided    18006
# Other                     999
# Consent withdrawn         188
# Name: count, dtype: int64
# <Axes: xlabel='Consumer consent provided?', ylabel='count'>

# %%
# Count the number of complaints sent to the company on each unique date
x = citigroup_data['Date sent to company'].value_counts()

# Print the counts to see how many complaints were sent on each date
print(x)
# Out:
# Date sent to company
# 2012-06-21    96
# 2021-12-03    78
# 2020-06-25    71
# 2016-06-30    61
# 2018-04-28    61
#               ..
# 2013-05-05     1
# 2014-09-07     1
# 2013-06-02     1
# 2013-03-30     1
# 2015-06-21     1
# Name: count, Length: 3919, dtype: int64

# %% [markdown]
# **Pre text processing**

# %% [markdown]
# Stemming

# %%
def text_stemming(text):
    # Convert the input to string in case it isn't (to avoid errors)
    text = str(text)

    # Initialize the Porter stemmer from NLTK (used to reduce words to their root form)
    stemmer = nltk.porter.PorterStemmer()

    # Split the text into individual words (tokens), stem each token, then join back into a single string
    stemmed = ' '.join([stemmer.stem(token) for token in text.split()])

    # Return the stemmed version of the text
    return stemmed

#End of Mingyang's Edits (7/15/25)

# %% [markdown]
# Task

# %%
#Begin Stacy's Edits for 7/16/25
def preProcess(s):
    # task: this function iterates through all the words in a string, 
    # removes all X's and slashes (redacted info), then pieces it back into a sentence
    # hint: regular expression to remove all X's: "[0-9]*[X]*[X]+[/]*[0-9]*"
    j = " ".join([re.sub(r'[0-9]*[X]*[X]+[/]*[0-9]*', '', x) for x in s.split()])

    return j

# %%
# converts the contents of 'Consumer complaint narrative' into string (str)
citigroup_data['Consumer complaint narrative'] = citigroup_data['Consumer complaint narrative'].astype(str)

# %%
# creates a new column, 'clean_text' with content from 'Consumer complaint narrative' with every response preprocessed
citigroup_data['clean_text'] = citigroup_data['Consumer complaint narrative'].apply(lambda x: preProcess(x))
# This uses a lambda function, in the format lambda argument: expression, where the expression is executed and returns a value


citigroup_data
# Out:
#         Date received                                            Product  \
# 55         2022-12-30  Money transfer, virtual currency, or money ser...
# 75         2022-12-26                        Checking or savings account
# 80         2022-12-25                        Credit card or prepaid card
# 154        2022-12-28                        Credit card or prepaid card
# 234        2022-12-07  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 3219444    2015-02-06                                           Mortgage
# 3219460    2013-02-02                                           Mortgage
# 3219498    2012-04-02                                           Mortgage
# 3220559    2016-09-29                            Bank account or service
# 3220570    2015-04-29                                           Mortgage
#
#                                         Sub-product  \
# 55                     Domestic (US) money transfer
# 75                                 Checking account
# 80       General-purpose credit card or charge card
# 154                               Store credit card
# 234                                Credit reporting
# ...                                             ...
# 3219444                                FHA mortgage
# 3219460                 Conventional fixed mortgage
# 3219498      Conventional adjustable mortgage (ARM)
# 3220559                            Checking account
# 3220570                 Conventional fixed mortgage
#
#                                                    Issue  \
# 55                             Other transaction problem
# 75                                    Closing an account
# 80       Problem with a purchase shown on your statement
# 154      Problem with a purchase shown on your statement
# 234                          Improper use of your report
# ...                                                  ...
# 3219444         Loan modification,collection,foreclosure
# 3219460         Application, originator, mortgage broker
# 3219498         Loan modification,collection,foreclosure
# 3220559          Account opening, closing, or management
# 3220570         Loan modification,collection,foreclosure
#
#                                                  Sub-issue  \
# 55                                                     NaN
# 75                                Can't close your account
# 80       Credit card company isn't resolving a dispute ...
# 154      Credit card company isn't resolving a dispute ...
# 234      Credit inquiries on your report that you don't...
# ...                                                    ...
# 3219444                                                NaN
# 3219460                                                NaN
# 3219498                                                NaN
# 3220559                                                NaN
# 3220570                                                NaN
#
#                               Consumer complaint narrative  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on XX/XX/2022. I informe...
# 80       Back in XXXX of 2021, I bought a XXXXXXXX XXXX...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  Near the end of XXXX 2016 I opened a Citigold ...
# 3220570  My father died in XX/XX/XXXX. Left me his only...
#
#                                    Company public response         Company  \
# 55       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 75       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 80       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 154      Company has responded to the consumer and the ...  CITIBANK, N.A.
# 234      Company has responded to the consumer and the ...  CITIBANK, N.A.
# ...                                                    ...             ...
# 3219444                                                NaN  CITIBANK, N.A.
# 3219460                                                NaN  CITIBANK, N.A.
# 3219498                                                NaN  CITIBANK, N.A.
# 3220559  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3220570                                                NaN  CITIBANK, N.A.
#
#         State ZIP code Tags Consumer consent provided? Submitted via  \
# 55         CA  91730.0  NaN           Consent provided           Web
# 75         WA  98102.0  NaN           Consent provided           Web
# 80         SC  29072.0  NaN           Consent provided           Web
# 154        DC  20012.0  NaN           Consent provided           Web
# 234        MD  20743.0  NaN           Consent provided           Web
# ...       ...      ...  ...                        ...           ...
# 3219444    AL  35813.0  NaN                        NaN           Web
# 3219460    PA  19086.0  NaN                        NaN           Web
# 3219498    MD  21076.0  NaN                        NaN         Phone
# 3220559    CA  90049.0  NaN           Consent provided           Web
# 3220570    OK  74066.0  NaN           Consent provided           Web
#
#         Date sent to company     Company response to consumer  \
# 55                2022-12-30          Closed with explanation
# 75                2022-12-26          Closed with explanation
# 80                2022-12-25      Closed with monetary relief
# 154               2022-12-28          Closed with explanation
# 234               2022-12-30          Closed with explanation
# ...                      ...                              ...
# 3219444           2015-02-06          Closed with explanation
# 3219460           2013-02-04          Closed with explanation
# 3219498           2012-04-04                Untimely response
# 3220559           2016-09-29  Closed with non-monetary relief
# 3220570           2015-04-29          Closed with explanation
#
#         Timely response? Consumer disputed?  Complaint ID  \
# 55                   Yes                NaN       6378719
# 75                   Yes                NaN       6361109
# 80                   Yes                NaN       6359652
# 154                  Yes                NaN       6368493
# 234                  Yes                NaN       6286123
# ...                  ...                ...           ...
# 3219444              Yes                 No       1228172
# 3219460              Yes                 No        289126
# 3219498               No                 No         43279
# 3220559              Yes                 No       2138969
# 3220570              Yes                 No       1352738
#
#                                                 clean_text
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on . I informed Citi of ...
# 80       Back in  of 2021, I bought a    . I had to sen...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  Near the end of  2016 I opened a Citigold chec...
# 3220570  My father died in . Left me his only son all h...
#
# [80527 rows x 19 columns]

# %% [markdown]
# Task

# %%
# task: create a new column in citigroup_data called 'stemmed_complaints' 
# and fill it in with the content from 'clean_text'
# but stemmed (with text_stemming applied to it)
citigroup_data['stemmed_complaints'] = citigroup_data['clean_text'].apply(text_stemming)

# show the data
citigroup_data
# Out:
#         Date received                                            Product  \
# 55         2022-12-30  Money transfer, virtual currency, or money ser...
# 75         2022-12-26                        Checking or savings account
# 80         2022-12-25                        Credit card or prepaid card
# 154        2022-12-28                        Credit card or prepaid card
# 234        2022-12-07  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 3219444    2015-02-06                                           Mortgage
# 3219460    2013-02-02                                           Mortgage
# 3219498    2012-04-02                                           Mortgage
# 3220559    2016-09-29                            Bank account or service
# 3220570    2015-04-29                                           Mortgage
#
#                                         Sub-product  \
# 55                     Domestic (US) money transfer
# 75                                 Checking account
# 80       General-purpose credit card or charge card
# 154                               Store credit card
# 234                                Credit reporting
# ...                                             ...
# 3219444                                FHA mortgage
# 3219460                 Conventional fixed mortgage
# 3219498      Conventional adjustable mortgage (ARM)
# 3220559                            Checking account
# 3220570                 Conventional fixed mortgage
#
#                                                    Issue  \
# 55                             Other transaction problem
# 75                                    Closing an account
# 80       Problem with a purchase shown on your statement
# 154      Problem with a purchase shown on your statement
# 234                          Improper use of your report
# ...                                                  ...
# 3219444         Loan modification,collection,foreclosure
# 3219460         Application, originator, mortgage broker
# 3219498         Loan modification,collection,foreclosure
# 3220559          Account opening, closing, or management
# 3220570         Loan modification,collection,foreclosure
#
#                                                  Sub-issue  \
# 55                                                     NaN
# 75                                Can't close your account
# 80       Credit card company isn't resolving a dispute ...
# 154      Credit card company isn't resolving a dispute ...
# 234      Credit inquiries on your report that you don't...
# ...                                                    ...
# 3219444                                                NaN
# 3219460                                                NaN
# 3219498                                                NaN
# 3220559                                                NaN
# 3220570                                                NaN
#
#                               Consumer complaint narrative  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on XX/XX/2022. I informe...
# 80       Back in XXXX of 2021, I bought a XXXXXXXX XXXX...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  Near the end of XXXX 2016 I opened a Citigold ...
# 3220570  My father died in XX/XX/XXXX. Left me his only...
#
#                                    Company public response         Company  \
# 55       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 75       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 80       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 154      Company has responded to the consumer and the ...  CITIBANK, N.A.
# 234      Company has responded to the consumer and the ...  CITIBANK, N.A.
# ...                                                    ...             ...
# 3219444                                                NaN  CITIBANK, N.A.
# 3219460                                                NaN  CITIBANK, N.A.
# 3219498                                                NaN  CITIBANK, N.A.
# 3220559  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3220570                                                NaN  CITIBANK, N.A.
#
#         State ZIP code Tags Consumer consent provided? Submitted via  \
# 55         CA  91730.0  NaN           Consent provided           Web
# 75         WA  98102.0  NaN           Consent provided           Web
# 80         SC  29072.0  NaN           Consent provided           Web
# 154        DC  20012.0  NaN           Consent provided           Web
# 234        MD  20743.0  NaN           Consent provided           Web
# ...       ...      ...  ...                        ...           ...
# 3219444    AL  35813.0  NaN                        NaN           Web
# 3219460    PA  19086.0  NaN                        NaN           Web
# 3219498    MD  21076.0  NaN                        NaN         Phone
# 3220559    CA  90049.0  NaN           Consent provided           Web
# 3220570    OK  74066.0  NaN           Consent provided           Web
#
#         Date sent to company     Company response to consumer  \
# 55                2022-12-30          Closed with explanation
# 75                2022-12-26          Closed with explanation
# 80                2022-12-25      Closed with monetary relief
# 154               2022-12-28          Closed with explanation
# 234               2022-12-30          Closed with explanation
# ...                      ...                              ...
# 3219444           2015-02-06          Closed with explanation
# 3219460           2013-02-04          Closed with explanation
# 3219498           2012-04-04                Untimely response
# 3220559           2016-09-29  Closed with non-monetary relief
# 3220570           2015-04-29          Closed with explanation
#
#         Timely response? Consumer disputed?  Complaint ID  \
# 55                   Yes                NaN       6378719
# 75                   Yes                NaN       6361109
# 80                   Yes                NaN       6359652
# 154                  Yes                NaN       6368493
# 234                  Yes                NaN       6286123
# ...                  ...                ...           ...
# 3219444              Yes                 No       1228172
# 3219460              Yes                 No        289126
# 3219498               No                 No         43279
# 3220559              Yes                 No       2138969
# 3220570              Yes                 No       1352738
#
#                                                 clean_text  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on . I informed Citi of ...
# 80       Back in  of 2021, I bought a    . I had to sen...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  Near the end of  2016 I opened a Citigold chec...
# 3220570  My father died in . Left me his only son all h...
#
#                                         stemmed_complaints
# 55       a wire transfer of {$23000.00} wa initi onlin ...
# 75       my father pass away on . i inform citi of hi p...
# 80       back in of 2021, i bought a . i had to send it...
# 154      i am a platinum card holder with macys. i gene...
# 234      i disput the unknown inquir and the compani an...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  near the end of 2016 i open a citigold check a...
# 3220570  my father die in . left me hi onli son all hi ...
#
# [80527 rows x 20 columns]

# %% [markdown]
# # Stop Words

# %% [markdown]
# Task

# %%
english_stop_words = nltk.corpus.stopwords.words('english')
# some common words might not be in the stop words list. If that ever becomes an issue, you can list a few of them and 
# add them into english_stop_words
def remove_stop_words(text):
    for stopword in english_stop_words:
        word = ' ' + stopword + ' '
        start_date = "" + stopword + "/"
        date = '/' + stopword
        # Task: remove word, start_date, and date everytime they appear in text
        text = text.replace(word, ' ')
        text = text.replace(start_date, '')
        text = text.replace(date, ' ')
    return text

# %%
print(english_stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# Task

# %%
# a new dataframe, info, is created which contains two columns from citigroup_data
info = citigroup_data[['Consumer complaint narrative', 'Company public response']]

# task: create a new column in citigroup_data called 'lowercase_stopworded_complaints',
# which contains content from 'stemmed_complaints' with stop words removed (remove_stop_words)
citigroup_data['lowercase_stopworded_complaints'] = citigroup_data['stemmed_complaints'].apply(remove_stop_words)

citigroup_data
# Out:
#         Date received                                            Product  \
# 55         2022-12-30  Money transfer, virtual currency, or money ser...
# 75         2022-12-26                        Checking or savings account
# 80         2022-12-25                        Credit card or prepaid card
# 154        2022-12-28                        Credit card or prepaid card
# 234        2022-12-07  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 3219444    2015-02-06                                           Mortgage
# 3219460    2013-02-02                                           Mortgage
# 3219498    2012-04-02                                           Mortgage
# 3220559    2016-09-29                            Bank account or service
# 3220570    2015-04-29                                           Mortgage
#
#                                         Sub-product  \
# 55                     Domestic (US) money transfer
# 75                                 Checking account
# 80       General-purpose credit card or charge card
# 154                               Store credit card
# 234                                Credit reporting
# ...                                             ...
# 3219444                                FHA mortgage
# 3219460                 Conventional fixed mortgage
# 3219498      Conventional adjustable mortgage (ARM)
# 3220559                            Checking account
# 3220570                 Conventional fixed mortgage
#
#                                                    Issue  \
# 55                             Other transaction problem
# 75                                    Closing an account
# 80       Problem with a purchase shown on your statement
# 154      Problem with a purchase shown on your statement
# 234                          Improper use of your report
# ...                                                  ...
# 3219444         Loan modification,collection,foreclosure
# 3219460         Application, originator, mortgage broker
# 3219498         Loan modification,collection,foreclosure
# 3220559          Account opening, closing, or management
# 3220570         Loan modification,collection,foreclosure
#
#                                                  Sub-issue  \
# 55                                                     NaN
# 75                                Can't close your account
# 80       Credit card company isn't resolving a dispute ...
# 154      Credit card company isn't resolving a dispute ...
# 234      Credit inquiries on your report that you don't...
# ...                                                    ...
# 3219444                                                NaN
# 3219460                                                NaN
# 3219498                                                NaN
# 3220559                                                NaN
# 3220570                                                NaN
#
#                               Consumer complaint narrative  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on XX/XX/2022. I informe...
# 80       Back in XXXX of 2021, I bought a XXXXXXXX XXXX...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  Near the end of XXXX 2016 I opened a Citigold ...
# 3220570  My father died in XX/XX/XXXX. Left me his only...
#
#                                    Company public response         Company  \
# 55       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 75       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 80       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 154      Company has responded to the consumer and the ...  CITIBANK, N.A.
# 234      Company has responded to the consumer and the ...  CITIBANK, N.A.
# ...                                                    ...             ...
# 3219444                                                NaN  CITIBANK, N.A.
# 3219460                                                NaN  CITIBANK, N.A.
# 3219498                                                NaN  CITIBANK, N.A.
# 3220559  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3220570                                                NaN  CITIBANK, N.A.
#
#         State ZIP code  ... Consumer consent provided? Submitted via  \
# 55         CA  91730.0  ...           Consent provided           Web
# 75         WA  98102.0  ...           Consent provided           Web
# 80         SC  29072.0  ...           Consent provided           Web
# 154        DC  20012.0  ...           Consent provided           Web
# 234        MD  20743.0  ...           Consent provided           Web
# ...       ...      ...  ...                        ...           ...
# 3219444    AL  35813.0  ...                        NaN           Web
# 3219460    PA  19086.0  ...                        NaN           Web
# 3219498    MD  21076.0  ...                        NaN         Phone
# 3220559    CA  90049.0  ...           Consent provided           Web
# 3220570    OK  74066.0  ...           Consent provided           Web
#
#         Date sent to company     Company response to consumer  \
# 55                2022-12-30          Closed with explanation
# 75                2022-12-26          Closed with explanation
# 80                2022-12-25      Closed with monetary relief
# 154               2022-12-28          Closed with explanation
# 234               2022-12-30          Closed with explanation
# ...                      ...                              ...
# 3219444           2015-02-06          Closed with explanation
# 3219460           2013-02-04          Closed with explanation
# 3219498           2012-04-04                Untimely response
# 3220559           2016-09-29  Closed with non-monetary relief
# 3220570           2015-04-29          Closed with explanation
#
#         Timely response? Consumer disputed? Complaint ID  \
# 55                   Yes                NaN      6378719
# 75                   Yes                NaN      6361109
# 80                   Yes                NaN      6359652
# 154                  Yes                NaN      6368493
# 234                  Yes                NaN      6286123
# ...                  ...                ...          ...
# 3219444              Yes                 No      1228172
# 3219460              Yes                 No       289126
# 3219498               No                 No        43279
# 3220559              Yes                 No      2138969
# 3220570              Yes                 No      1352738
#
#                                                 clean_text  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on . I informed Citi of ...
# 80       Back in  of 2021, I bought a    . I had to sen...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  Near the end of  2016 I opened a Citigold chec...
# 3220570  My father died in . Left me his only son all h...
#
#                                         stemmed_complaints  \
# 55       a wire transfer of {$23000.00} wa initi onlin ...
# 75       my father pass away on . i inform citi of hi p...
# 80       back in of 2021, i bought a . i had to send it...
# 154      i am a platinum card holder with macys. i gene...
# 234      i disput the unknown inquir and the compani an...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  near the end of 2016 i open a citigold check a...
# 3220570  my father die in . left me hi onli son all hi ...
#
#                            lowercase_stopworded_complaints
# 55       a wire transfer {$23000.00} wa initi onlin , c...
# 75       my father pass away . inform citi hi pass tele...
# 80       back 2021, bought . send back twice within 2 m...
# 154      i platinum card holder macys. gener buy produc...
# 234      i disput unknown inquir compani credit bureau ...
# ...                                                    ...
# 3219444                                                nan
# 3219460                                                nan
# 3219498                                                nan
# 3220559  near end 2016 open citigold check account prom...
# 3220570  my father die . left hi onli son hi belongings...
#
# [80527 rows x 21 columns]

# %%
# creates a new dataframe that contains rows from citigroup_data where content in 'lowercase_stopworded_complaints' is
# not 'nan' (undefined)
citigroup_data1 = citigroup_data[~citigroup_data['lowercase_stopworded_complaints'].isin(['nan'])]
citigroup_data1
# Out:
#         Date received                                            Product  \
# 55         2022-12-30  Money transfer, virtual currency, or money ser...
# 75         2022-12-26                        Checking or savings account
# 80         2022-12-25                        Credit card or prepaid card
# 154        2022-12-28                        Credit card or prepaid card
# 234        2022-12-07  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 3219098    2016-08-11                                    Debt collection
# 3219099    2017-03-27                                           Mortgage
# 3219100    2015-05-09                                        Credit card
# 3220559    2016-09-29                            Bank account or service
# 3220570    2015-04-29                                           Mortgage
#
#                                         Sub-product  \
# 55                     Domestic (US) money transfer
# 75                                 Checking account
# 80       General-purpose credit card or charge card
# 154                               Store credit card
# 234                                Credit reporting
# ...                                             ...
# 3219098                                 Credit card
# 3219099                                FHA mortgage
# 3219100                                         NaN
# 3220559                            Checking account
# 3220570                 Conventional fixed mortgage
#
#                                                    Issue  \
# 55                             Other transaction problem
# 75                                    Closing an account
# 80       Problem with a purchase shown on your statement
# 154      Problem with a purchase shown on your statement
# 234                          Improper use of your report
# ...                                                  ...
# 3219098                            Communication tactics
# 3219099         Loan modification,collection,foreclosure
# 3219100                                         Late fee
# 3220559          Account opening, closing, or management
# 3220570         Loan modification,collection,foreclosure
#
#                                                  Sub-issue  \
# 55                                                     NaN
# 75                                Can't close your account
# 80       Credit card company isn't resolving a dispute ...
# 154      Credit card company isn't resolving a dispute ...
# 234      Credit inquiries on your report that you don't...
# ...                                                    ...
# 3219098            Called after sent written cease of comm
# 3219099                                                NaN
# 3219100                                                NaN
# 3220559                                                NaN
# 3220570                                                NaN
#
#                               Consumer complaint narrative  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on XX/XX/2022. I informe...
# 80       Back in XXXX of 2021, I bought a XXXXXXXX XXXX...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219098  I sent a letter asking for debt verification a...
# 3219099  I spoke with a representative @ CitiMortgage o...
# 3219100  Purchased XXXX bras and opened a macy 's card....
# 3220559  Near the end of XXXX 2016 I opened a Citigold ...
# 3220570  My father died in XX/XX/XXXX. Left me his only...
#
#                                    Company public response         Company  \
# 55       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 75       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 80       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 154      Company has responded to the consumer and the ...  CITIBANK, N.A.
# 234      Company has responded to the consumer and the ...  CITIBANK, N.A.
# ...                                                    ...             ...
# 3219098  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3219099  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3219100   Company chooses not to provide a public response  CITIBANK, N.A.
# 3220559  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3220570                                                NaN  CITIBANK, N.A.
#
#         State ZIP code  ... Consumer consent provided? Submitted via  \
# 55         CA  91730.0  ...           Consent provided           Web
# 75         WA  98102.0  ...           Consent provided           Web
# 80         SC  29072.0  ...           Consent provided           Web
# 154        DC  20012.0  ...           Consent provided           Web
# 234        MD  20743.0  ...           Consent provided           Web
# ...       ...      ...  ...                        ...           ...
# 3219098    CA  92506.0  ...           Consent provided           Web
# 3219099    GA  30326.0  ...           Consent provided           Web
# 3219100    PA  16403.0  ...           Consent provided           Web
# 3220559    CA  90049.0  ...           Consent provided           Web
# 3220570    OK  74066.0  ...           Consent provided           Web
#
#         Date sent to company     Company response to consumer  \
# 55                2022-12-30          Closed with explanation
# 75                2022-12-26          Closed with explanation
# 80                2022-12-25      Closed with monetary relief
# 154               2022-12-28          Closed with explanation
# 234               2022-12-30          Closed with explanation
# ...                      ...                              ...
# 3219098           2016-08-11          Closed with explanation
# 3219099           2017-03-27          Closed with explanation
# 3219100           2015-05-09          Closed with explanation
# 3220559           2016-09-29  Closed with non-monetary relief
# 3220570           2015-04-29          Closed with explanation
#
#         Timely response? Consumer disputed? Complaint ID  \
# 55                   Yes                NaN      6378719
# 75                   Yes                NaN      6361109
# 80                   Yes                NaN      6359652
# 154                  Yes                NaN      6368493
# 234                  Yes                NaN      6286123
# ...                  ...                ...          ...
# 3219098              Yes                 No      2058119
# 3219099              Yes                 No      2406658
# 3219100              Yes                 No      1368346
# 3220559              Yes                 No      2138969
# 3220570              Yes                 No      1352738
#
#                                                 clean_text  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on . I informed Citi of ...
# 80       Back in  of 2021, I bought a    . I had to sen...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219098  I sent a letter asking for debt verification a...
# 3219099  I spoke with a representative @ CitiMortgage o...
# 3219100  Purchased  bras and opened a macy 's card. I p...
# 3220559  Near the end of  2016 I opened a Citigold chec...
# 3220570  My father died in . Left me his only son all h...
#
#                                         stemmed_complaints  \
# 55       a wire transfer of {$23000.00} wa initi onlin ...
# 75       my father pass away on . i inform citi of hi p...
# 80       back in of 2021, i bought a . i had to send it...
# 154      i am a platinum card holder with macys. i gene...
# 234      i disput the unknown inquir and the compani an...
# ...                                                    ...
# 3219098  i sent a letter ask for debt verif and to be p...
# 3219099  i spoke with a repres @ citimortgag on who adv...
# 3219100  purchas bra and open a maci 's card. i paid th...
# 3220559  near the end of 2016 i open a citigold check a...
# 3220570  my father die in . left me hi onli son all hi ...
#
#                            lowercase_stopworded_complaints
# 55       a wire transfer {$23000.00} wa initi onlin , c...
# 75       my father pass away . inform citi hi pass tele...
# 80       back 2021, bought . send back twice within 2 m...
# 154      i platinum card holder macys. gener buy produc...
# 234      i disput unknown inquir compani credit bureau ...
# ...                                                    ...
# 3219098  i sent letter ask debt verif place call list. ...
# 3219099  i spoke repres @ citimortgag advis addit docum...
# 3219100  purchas bra open maci 's card. paid thi follow...
# 3220559  near end 2016 open citigold check account prom...
# 3220570  my father die . left hi onli son hi belongings...
#
# [29617 rows x 21 columns]

# %% [markdown]
# # TF-IDF!

# %% [markdown]
# Task

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# new dataframe: documents
documents = citigroup_data1

vectorizer = TfidfVectorizer()
# the vectorizer is fed the dataframe containing pre-processed complaints, and outputs a matrix:
# the rows are document entries, the cols are individual words. Each element is a number (TF-IDF scores)
tfidf_matrix = vectorizer.fit_transform(documents)

# feature_names stores all unique words from document
feature_names = vectorizer.get_feature_names_out()

# empty dictionary. Will be populated with words and their corresponding TF-IDF scores, as long as they are non-zero
tfidf_values = {}

# populating the dictionary
# this for loop iterates through each row in documents, storing the entry from each index into doc
for doc_index, doc in enumerate(documents):
    # in each row of the matrix, returns the indices where the TF-IDF score is non-zero, then pulls out the column indices
    feature = tfidf_matrix[doc_index, :].nonzero()[1]

    # print(tfidf_matrix[doc_index, :].nonzero())
    
    # zip essentially distributes each element of each list into tuples; here it distributes the index of each word
    # with its corresponding TFIDF score
    tfidf_doc_values = zip(feature, [tfidf_matrix[doc_index, x] for x in feature])
    # adding to the dictionary: the key is the actual word, and the value is the tfidf score
    tfidf_values[doc_index] = {feature_names[i]: value for i, value in tfidf_doc_values}

# Task: try to print out the values in the dictionary (tfidf_values) on your own. 
# f-notation recommended, and using for loops.
# the final print should look something like:
# Document 1:
# date: 0.6609119307285228
# received: 0.7504634700108301


# Document 2:
# product: 1.0


# Document 3:
# product: 0.7071067811865476
# sub: 0.7071067811865476
#...

for doc_index, values in tfidf_values.items():
    print(f'Document {doc_index + 1}:')
    for word, tfidf_value in values.items():
        print(f'{word}: {tfidf_value}')
    print('\n')

# End of Stacy's Tutorial (7/16/25)
# Out:
# Document 1:
# received: 0.7504634700108301
# date: 0.6609119307285228
#
#
# Document 2:
# product: 1.0
#
#
# Document 3:
# sub: 0.7071067811865476
# product: 0.7071067811865476
#
#
# Document 4:
# issue: 1.0
#
#
# Document 5:
# issue: 0.7071067811865476
# sub: 0.7071067811865476
#
#
# Document 6:
# narrative: 0.65809800368284
# complaint: 0.5795682796077143
# consumer: 0.4806325278434814
#
#
# Document 7:
# response: 0.5407364413315685
# public: 0.6793112464346958
# company: 0.49612531832533124
#
#
# Document 8:
# company: 1.0
#
#
# Document 9:
# state: 1.0
#
#
# Document 10:
# code: 0.7071067811865475
# zip: 0.7071067811865475
#
#
# Document 11:
# tags: 1.0
#
#
# Document 12:
# provided: 0.6282737896595033
# consent: 0.6282737896595033
# consumer: 0.4588508368236594
#
#
# Document 13:
# via: 0.7071067811865475
# submitted: 0.7071067811865475
#
#
# Document 14:
# to: 0.5014385652506749
# sent: 0.5693819526914362
# company: 0.4158400203299057
# date: 0.5014385652506749
#
#
# Document 15:
# to: 0.5596797070127751
# response: 0.5058740008938791
# company: 0.46413905285900786
# consumer: 0.46413905285900786
#
#
# Document 16:
# timely: 0.7823904668409976
# response: 0.6227882123132438
#
#
# Document 17:
# disputed: 0.8075578331233998
# consumer: 0.5897883910022637
#
#
# Document 18:
# id: 0.7504634700108301
# complaint: 0.6609119307285228
#
#
# Document 19:
# clean_text: 1.0
#
#
# Document 20:
# stemmed_complaints: 1.0
#
#
# Document 21:
# lowercase_stopworded_complaints: 1.0

# %%
# Begin Mingyang's Edit for 7/17/25 
  
# Displays our current Data Frame that we declared before
documents
# Out:
#         Date received                                            Product  \
# 55         2022-12-30  Money transfer, virtual currency, or money ser...
# 75         2022-12-26                        Checking or savings account
# 80         2022-12-25                        Credit card or prepaid card
# 154        2022-12-28                        Credit card or prepaid card
# 234        2022-12-07  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 3219098    2016-08-11                                    Debt collection
# 3219099    2017-03-27                                           Mortgage
# 3219100    2015-05-09                                        Credit card
# 3220559    2016-09-29                            Bank account or service
# 3220570    2015-04-29                                           Mortgage
#
#                                         Sub-product  \
# 55                     Domestic (US) money transfer
# 75                                 Checking account
# 80       General-purpose credit card or charge card
# 154                               Store credit card
# 234                                Credit reporting
# ...                                             ...
# 3219098                                 Credit card
# 3219099                                FHA mortgage
# 3219100                                         NaN
# 3220559                            Checking account
# 3220570                 Conventional fixed mortgage
#
#                                                    Issue  \
# 55                             Other transaction problem
# 75                                    Closing an account
# 80       Problem with a purchase shown on your statement
# 154      Problem with a purchase shown on your statement
# 234                          Improper use of your report
# ...                                                  ...
# 3219098                            Communication tactics
# 3219099         Loan modification,collection,foreclosure
# 3219100                                         Late fee
# 3220559          Account opening, closing, or management
# 3220570         Loan modification,collection,foreclosure
#
#                                                  Sub-issue  \
# 55                                                     NaN
# 75                                Can't close your account
# 80       Credit card company isn't resolving a dispute ...
# 154      Credit card company isn't resolving a dispute ...
# 234      Credit inquiries on your report that you don't...
# ...                                                    ...
# 3219098            Called after sent written cease of comm
# 3219099                                                NaN
# 3219100                                                NaN
# 3220559                                                NaN
# 3220570                                                NaN
#
#                               Consumer complaint narrative  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on XX/XX/2022. I informe...
# 80       Back in XXXX of 2021, I bought a XXXXXXXX XXXX...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219098  I sent a letter asking for debt verification a...
# 3219099  I spoke with a representative @ CitiMortgage o...
# 3219100  Purchased XXXX bras and opened a macy 's card....
# 3220559  Near the end of XXXX 2016 I opened a Citigold ...
# 3220570  My father died in XX/XX/XXXX. Left me his only...
#
#                                    Company public response         Company  \
# 55       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 75       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 80       Company has responded to the consumer and the ...  CITIBANK, N.A.
# 154      Company has responded to the consumer and the ...  CITIBANK, N.A.
# 234      Company has responded to the consumer and the ...  CITIBANK, N.A.
# ...                                                    ...             ...
# 3219098  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3219099  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3219100   Company chooses not to provide a public response  CITIBANK, N.A.
# 3220559  Company has responded to the consumer and the ...  CITIBANK, N.A.
# 3220570                                                NaN  CITIBANK, N.A.
#
#         State ZIP code  ... Consumer consent provided? Submitted via  \
# 55         CA  91730.0  ...           Consent provided           Web
# 75         WA  98102.0  ...           Consent provided           Web
# 80         SC  29072.0  ...           Consent provided           Web
# 154        DC  20012.0  ...           Consent provided           Web
# 234        MD  20743.0  ...           Consent provided           Web
# ...       ...      ...  ...                        ...           ...
# 3219098    CA  92506.0  ...           Consent provided           Web
# 3219099    GA  30326.0  ...           Consent provided           Web
# 3219100    PA  16403.0  ...           Consent provided           Web
# 3220559    CA  90049.0  ...           Consent provided           Web
# 3220570    OK  74066.0  ...           Consent provided           Web
#
#         Date sent to company     Company response to consumer  \
# 55                2022-12-30          Closed with explanation
# 75                2022-12-26          Closed with explanation
# 80                2022-12-25      Closed with monetary relief
# 154               2022-12-28          Closed with explanation
# 234               2022-12-30          Closed with explanation
# ...                      ...                              ...
# 3219098           2016-08-11          Closed with explanation
# 3219099           2017-03-27          Closed with explanation
# 3219100           2015-05-09          Closed with explanation
# 3220559           2016-09-29  Closed with non-monetary relief
# 3220570           2015-04-29          Closed with explanation
#
#         Timely response? Consumer disputed? Complaint ID  \
# 55                   Yes                NaN      6378719
# 75                   Yes                NaN      6361109
# 80                   Yes                NaN      6359652
# 154                  Yes                NaN      6368493
# 234                  Yes                NaN      6286123
# ...                  ...                ...          ...
# 3219098              Yes                 No      2058119
# 3219099              Yes                 No      2406658
# 3219100              Yes                 No      1368346
# 3220559              Yes                 No      2138969
# 3220570              Yes                 No      1352738
#
#                                                 clean_text  \
# 55       A Wire transfer of {$23000.00} was initiated o...
# 75       My father passed away on . I informed Citi of ...
# 80       Back in  of 2021, I bought a    . I had to sen...
# 154      I am a platinum card holder with Macys. I gene...
# 234      I disputed the unknown inquires and the compan...
# ...                                                    ...
# 3219098  I sent a letter asking for debt verification a...
# 3219099  I spoke with a representative @ CitiMortgage o...
# 3219100  Purchased  bras and opened a macy 's card. I p...
# 3220559  Near the end of  2016 I opened a Citigold chec...
# 3220570  My father died in . Left me his only son all h...
#
#                                         stemmed_complaints  \
# 55       a wire transfer of {$23000.00} wa initi onlin ...
# 75       my father pass away on . i inform citi of hi p...
# 80       back in of 2021, i bought a . i had to send it...
# 154      i am a platinum card holder with macys. i gene...
# 234      i disput the unknown inquir and the compani an...
# ...                                                    ...
# 3219098  i sent a letter ask for debt verif and to be p...
# 3219099  i spoke with a repres @ citimortgag on who adv...
# 3219100  purchas bra and open a maci 's card. i paid th...
# 3220559  near the end of 2016 i open a citigold check a...
# 3220570  my father die in . left me hi onli son all hi ...
#
#                            lowercase_stopworded_complaints
# 55       a wire transfer {$23000.00} wa initi onlin , c...
# 75       my father pass away . inform citi hi pass tele...
# 80       back 2021, bought . send back twice within 2 m...
# 154      i platinum card holder macys. gener buy produc...
# 234      i disput unknown inquir compani credit bureau ...
# ...                                                    ...
# 3219098  i sent letter ask debt verif place call list. ...
# 3219099  i spoke repres @ citimortgag advis addit docum...
# 3219100  purchas bra open maci 's card. paid thi follow...
# 3220559  near end 2016 open citigold check account prom...
# 3220570  my father die . left hi onli son hi belongings...
#
# [29617 rows x 21 columns]

# %%
# Importing Gensim's Dictionary object used for mapping words to IDs
from gensim import corpora

# Print out the available columns in the DataFrame to confirm structure
print("Column names in the DataFrame:", citigroup_data.columns)

# Specify the column that contains preprocessed complaint text
text_column_name = 'lowercase_stopworded_complaints'

# Check that this column actually exists; raise an error if it doesn't
if text_column_name not in citigroup_data.columns:
    raise ValueError(f"Column '{text_column_name}' not found in the DataFrame")

# Convert the entire column to a list of strings (each representing one complaint)
texts = citigroup_data[text_column_name].tolist()

# Validate that the list is not empty
if not texts:
    # Brings up an error that says "No data found in the text column"
    raise ValueError("No data found in the text column")

# Initialize an empty list to store tokenized sentences
tokenized = []

# Loop over each sentence in the list
for sentence in texts:
    # Use gensim's built-in tokenizer to split sentences into tokens, lowercasing everyhting, removing punctuation, and removing accent marks (deacc=True) 
    # deacc=True : treating words like "résumé" and "resume" as the same
    tokenized.append(gensim.utils.simple_preprocess(sentence, deacc=True))

# Show a preview of the tokenized text to verify everything is working
print("First few tokenized sentences:", tokenized[:5])

# Create a dictionary: assigns a unique integer ID to each word in the corpus
dictionary = corpora.Dictionary(tokenized)

# Create the corpus: for each document, generate a list of tuples (word_id, word_frequency)
# .doc2bow converts a document into bag of words format: a list of (word_id, word_frequency)
# example: the dictionary is this {'bank': 0, 'charged': 1, 'me': 2, 'extra': 3, 'fees': 4, 'unauthorized': 5}

# Apply the doc2bow mehtod to each text in the tokenized list
corpus = [dictionary.doc2bow(text) for text in tokenized]
# After doc2bow, the output will be [(0, 1), (1, 1), (4, 2)]
# Out:
# Column names in the DataFrame: Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID', 'clean_text',
#        'stemmed_complaints', 'lowercase_stopworded_complaints'],
#       dtype='object')
# First few tokenized sentences: [['wire', 'transfer', 'wa', 'initi', 'onlin', 'corpor', 'account', 'anoth', 'corpor', 'account', 'name', 'wire', 'transfer', 'wa', 'unsuccess', 'ofac', 'wa', 'cite', 'reason', 'supervisor', 'citibank', 'wire', 'department', 'avail', 'inform', 'request', 'ha', 'provided', 'subsequ', 'cancel', 'wire', 'transfer', 'date', 'fund', 'return', 'reason', 'abl', 'provid', 'ownership', 'detail', 'neither', 'oblig', 'expect', 'know', 'ownership', 'detail', 'valid', 'reason', 'citibank', 'withhold', 'fund', 'fund', 'urgent', 'requir'], ['my', 'father', 'pass', 'away', 'inform', 'citi', 'hi', 'pass', 'telephon', 'citi', 'alleg', 'would', 'contact', 'steps', 'never', 'did', 'contact', 'citi', 'request', 'fax', 'includ', 'death', 'certificate', 'live', 'trust', 'documents', 'letter', 'intent', 'fax', 'abov', 'citi', 'confirm', 'receipt', 'end', 'call', 'next', 'day', 'confirm', 'receiv', 'it', 'letter', 'intent', 'includ', 'instruct', 'close', 'accounts', 'includ', 'check', 'account', 'save', 'account', 'citi', 'sent', 'letter', 'alleg', 'frozen', 'father', 'check', 'account', 'citi', 'process', 'withdraw', 'third', 'parti', 'check', 'account', 'despit', 'alleg', 'account', 'wa', 'closed', 'thi', 'amount', 'wa', 'citi', 'charg', 'servic', 'fee', 'father', 'save', 'account', 'month', 'sinc', 'father', 'ha', 'died', 'citi', 'ha', 'contact', 'onc', 'indic', 'taken', 'ani', 'action', 'onli', 'receiv', 'form', 'letter', 'fals', 'statement', 'father', 'check', 'account', 'wa', 'frozen', 'citi', 'continu', 'charg', 'fee', 'process', 'transact', 'hi', 'check', 'account', 'hi', 'save', 'account', 'violat', 'cfr'], ['back', 'bought', 'send', 'back', 'twice', 'within', 'month', 'receiv', 'cost', 'around', 'ship', 'time', 'everi', 'time', 'told', 'wa', 'fault', 'one', 'reason', 'anoth', 'would', 'repair', 'send', 'new', 'unit', 'second', 'time', 'told', 'keep', 'refund', 'money', 'not', 'sent', 'back', 'broken', 'file', 'disput', 'citi', 'gave', 'reasons', 'disput', 'site', 'wa', 'abl', 'forward', 'email', 'commun', 'know', 'ask', 'addit', 'inform', 'time', 'limit', 'pass', 'log', 'make', 'monthli', 'payment', 'also', 'provid', 'merchant', 'respons', 'send', 'ani', 'kind', 'prior', 'notif', 'us', 'mail', 'email', 'need', 'info', 'onli', 'email', 'receiv', 'wa', 'show', 'track', 'number', 'return', 'amplified', 'anoth', 'instance', 'issu', 'phone', 'service', 'sure', 'happen', 'equip', 'quit', 'work', 'dial', 'tone', 'know', 'kept', 'charg', 'monthli', 'fee', 'servic', 'have', 'citi', 'refund', 'monthli', 'charg', 'except', 'one', 'month', 'reason', 'somehow', 'need', 'inform', 'one', 'month', 'again', 'wa', 'notified', 'thi', 'seem', 'pattern', 'neglig', 'citi', 'behalf', 'protect', 'financi', 'interest', 'customers', 'whatever', 'su', 'citi', 'mastercard', 'this', 'thank', 'you'], ['platinum', 'card', 'holder', 'macys', 'gener', 'buy', 'product', 'sales', 'sales', 'purchas', 'cloth', 'item', 'well', 'ear', 'necklace', 'item', 'deliv', 'separ', 'deliveries', 'return', 'home', 'around', 'find', 'open', 'box', 'maci', 'packag', 'door', 'insid', 'box', 'empti', 'case', 'receipt', 'immedi', 'call', 'maci', 'close', 'went', 'ahead', 'place', 'anoth', 'order', 'delivered', 'call', 'maci', 'report', 'find', 'also', 'let', 'know', 'sinc', 'place', 'anoth', 'order', 'maci', 'assur', 'wa', 'go', 'receiv', 'credit', 'wait', 'week', 'see', 'ani', 'credit', 'maci', 'account', 'call', 'maci', 'credit', 'well', 'wa', 'told', 'file', 'polic', 'report', 'wa', 'assign', 'detect', 'case', 'also', 'reach', 'deliveri', 'guy', 'neighborhood', 'turn', 'call', 'hi', 'supervisor', 'upon', 'investigation', 'wa', 'told', 'packag', 'wa', 'deliv', 'wrong', 'address', 'promis', 'go', 'locat', 'get', 'back', 'me', 'ask', 'knew', 'empti', 'packag', 'end', 'door', 'said', 'no', 'day', 'later', 'inform', 'went', 'locat', 'packag', 'wa', 'deliv', 'time', 'respons', 'reach', 'maci', 'sort', 'relay', 'macys', 'maci', 'told', 'contact', 'file', 'claim', 'state ...

# %%
# Import the TF-IDF model for weighting words based on frequency and uniqueness
from gensim.models import TfidfModel

# Create a TF-IDF model using the bag-of-words corpus
# This model will learn the importance (weight) of each word across the entire set of documents and calculating IDF scores for all words in the corpus
tfidf = TfidfModel(corpus)

# Apply the trained TF-IDF model to the original corpus
corpus_tfidf = tfidf[corpus]
# Iterates over each document in the BoW corpus
# Calculates the TF-IDF score for each (word_id, count) in that document.
# Returns a list of (word_id, tf-idf_score) for every document.

# Ex:
# BoWs: [(0, 1), (1, 2), (3, 1)]
# to TF-IDF: [(0, 0.32), (1, 0.50), (3, 0.76)]

# %%
# Print the first few entries of the dictionary and corpus to verify
print("Dictionary:", dictionary.token2id) # Maps each unique word (token) to an unique id
print("Corpus:", corpus[0])
# Out:
# Dictionary: {'abl': 0, 'account': 1, 'anoth': 2, 'avail': 3, 'cancel': 4, 'cite': 5, 'citibank': 6, 'corpor': 7, 'date': 8, 'department': 9, 'detail': 10, 'expect': 11, 'fund': 12, 'ha': 13, 'inform': 14, 'initi': 15, 'know': 16, 'name': 17, 'neither': 18, 'oblig': 19, 'ofac': 20, 'onlin': 21, 'ownership': 22, 'provid': 23, 'provided': 24, 'reason': 25, 'request': 26, 'requir': 27, 'return': 28, 'subsequ': 29, 'supervisor': 30, 'transfer': 31, 'unsuccess': 32, 'urgent': 33, 'valid': 34, 'wa': 35, 'wire': 36, 'withhold': 37, 'abov': 38, 'accounts': 39, 'action': 40, 'alleg': 41, 'amount': 42, 'ani': 43, 'away': 44, 'call': 45, 'certificate': 46, 'cfr': 47, 'charg': 48, 'check': 49, 'citi': 50, 'close': 51, 'closed': 52, 'confirm': 53, 'contact': 54, 'continu': 55, 'day': 56, 'death': 57, 'despit': 58, 'did': 59, 'died': 60, 'documents': 61, 'end': 62, 'fals': 63, 'father': 64, 'fax': 65, 'fee': 66, 'form': 67, 'frozen': 68, 'hi': 69, 'includ': 70, 'indic': 71, 'instruct': 72, 'intent': 73, 'it': 74, 'letter': 75, 'live': 76, 'month': 77, 'my': 78, 'never': 79, 'next': 80, 'onc': 81, 'onli': 82, 'parti': 83, 'pass': 84, 'process': 85, 'receipt': 86, 'receiv': 87, 'save': 88, 'sent': 89, 'servic': 90, 'sinc': 91, 'statement': 92, 'steps': 93, 'taken': 94, 'telephon': 95, 'thi': 96, 'third': 97, 'transact': 98, 'trust': 99, 'violat': 100, 'withdraw': 101, 'would': 102, 'addit': 103, 'again': 104, 'also': 105, 'amplified': 106, 'around': 107, 'ask': 108, 'back': 109, 'behalf': 110, 'bought': 111, 'broken': 112, 'commun': 113, 'cost': 114, 'customers': 115, 'dial': 116, 'disput': 117, 'email': 118, 'equip': 119, 'everi': 120, 'except': 121, 'fault': 122, 'file': 123, 'financi': 124, 'forward': 125, 'gave': 126, 'happen': 127, 'have': 128, 'info': 129, 'instance': 130, 'interest': 131, 'issu': 132, 'keep': 133, 'kept': 134, 'kind': 135, 'limit': 136, 'log': 137, 'mail': 138, 'make': 139, 'mastercard': 140, 'merchant': 141, 'money': 142, 'monthli': 143, 'need': 144, 'neglig': 145, 'new': 146, 'not': 147, 'notif': 148, 'notified': 149, 'number': 150, 'one': 151, 'pattern': 152, 'payment': 153, 'phone': 154, 'prior': 155, 'protect': 156, 'quit': 157, 'reasons': 158, 'refund': 159, 'repair': 160, 'respons': 161, 'second': 162, 'seem': 163, 'send': 164, 'service': 165, 'ship': 166, 'show': 167, 'site': 168, 'somehow': 169, 'su': 170, 'sure': 171, 'thank': 172, 'this': 173, 'time': 174, 'told': 175, 'tone': 176, 'track': 177, 'twice': 178, 'unit': 179, 'us': 180, 'whatever': 181, 'within': 182, 'work': 183, 'you': 184, 'address': 185, 'ahead': 186, 'assign': 187, 'assur': 188, 'box': 189, 'buy': 190, 'card': 191, 'case': 192, 'claim': 193, 'cloth': 194, 'credit': 195, 'deliv': 196, 'delivered': 197, 'deliveri': 198, 'deliveries': 199, 'denial': 200, 'detect': 201, 'door': 202, 'ear': 203, 'empti': 204, 'even': 205, 'find': 206, 'gener': 207, 'get': 208, 'go': 209, 'guy': 210, 'holder': 211, 'home': 212, 'house': 213, 'immedi': 214, 'insid': 215, 'insist': 216, 'instead': 217, 'investigation': 218, 'item': 219, 'items': 220, 'knew': 221, 'later': 222, 'left': 223, 'let': 224, 'lie': 225, 'locat': 226, 'maci': 227, 'macys': 228, 'mailbox': 229, 'me': 230, 'miss': 231, 'necklace': 232, 'neighborhood': 233, 'no': 234, 'open': 235, 'order': 236, 'packag': 237, 'pay': 238, 'place': 239, 'platinum': 240, 'polic': 241, 'product': 242, 'promis': 243, 'proven': 244, 'purchas': 245, 'reach': 246, 'relay': 247, 'report': 248, 'said': 249, 'sales': 250, 'see': 251, 'separ': 252, 'sort': 253, 'state': 254, 'surprise': 255, 'though': 256, 'turn': 257, 'upon': 258, 'wait': 259, 'week': 260, 'well': 261, 'went': 262, 'wrong': 263, 'yesterday': 264, 'bureau': 265, 'compani': 266, 'inquir': 267, 'refus': 268, 'remov': 269, 'them': 270, 'unknown': 271, 'nan': 272, 'fraudul': 273, 'accur': 274, 'accurate': 275, 'act': 276, 'agenc': 277, 'and': 278, 'assist': 279, 'attempt': 280, 'balanc': 281, 'bring': 282, 'cfpb': 283, 'clear': 284, 'conduct': 285, 'correct': ...
# Corpus: [(0, 1), (1, 2), (2, 1), (3, 1), (4, 1), (5, 1), (6, 2), (7, 2), (8, 1), (9, 1), (10, 2), (11, 1), (12, 3), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 2), (23, 1), (24, 1), (25, 3), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 3), (32, 1), (33, 1), (34, 1), (35, 3), (36, 4), (37, 1)]

# %%
from gensim.models import LdaModel

# Create the LDA (Latent Dirichlet Allocation) topic model
# - corpus: the bag-of-words representation of documents
# - num_topics: number of topics we want the model to discover. The number can be tricky to find, usually through experimentation and trial and error
# example of topics: 
    # "I was charged extra fees on my mortgage" 
    # "Unauthorized credit card transaction"
    # Topic 0: 'mortgage', 'fees', 'rate'
    # Topic 1: 'unauthorized', 'credit', 'fraud'
# LDA doesn't need a specific word to appear in every document in a topic.
# It finds patterns across many documents and identifies which words tend to appear together frequently.
# - id2word: the dictionary mapping of word IDs to actual words
# - passes: number of times the model will go through the entire corpus (higher = better quality but slower)
lda = LdaModel(corpus, num_topics=4, id2word=dictionary, passes=10)

# Another way to determine the number of topics is by using coherence score, it measures how understandable and meaningful the topics are.
from gensim.models import CoherenceModel
coherence_model = CoherenceModel(model=lda, texts=tokenized, dictionary=dictionary, coherence='c_v')
coherence = coherence_model.get_coherence()
print("Coherence Score:", coherence)
# Higher scores (closer to 1.0) = more interpretable topics
# Try this for different topic numbers and pick the best one


# Loop through each generated topic and print the top words associated with it
# lda.print_topics(-1) returns all topics with their most relevant words
for idx, word in lda.print_topics(-1):
    print(f"Topic: {idx}\nWords: {word}\n")
# Out:
# /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/jaelynliou/Library/Python/3.8/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Coherence Score: 0.4816745103538521
# Topic: 0
# Words: 0.038*"credit" + 0.034*"wa" + 0.029*"card" + 0.027*"payment" + 0.022*"thi" + 0.018*"charg" + 0.015*"account" + 0.011*"pay" + 0.010*"balanc" + 0.010*"late"
#
# Topic: 1
# Words: 0.312*"nan" + 0.049*"report" + 0.033*"credit" + 0.018*"thi" + 0.018*"debt" + 0.016*"account" + 0.012*"inform" + 0.012*"consum" + 0.010*"inquiri" + 0.010*"ani"
#
# Topic: 2
# Words: 0.037*"wa" + 0.031*"account" + 0.022*"call" + 0.016*"thi" + 0.016*"citibank" + 0.012*"bank" + 0.012*"told" + 0.011*"check" + 0.011*"citi" + 0.011*"card"
#
# Topic: 3
# Words: 0.021*"citi" + 0.020*"wa" + 0.016*"thi" + 0.015*"citibank" + 0.013*"account" + 0.012*"receiv" + 0.009*"offer" + 0.008*"disput" + 0.008*"would" + 0.008*"loan"

# %%
from IPython.display import display, HTML  # Tools to display HTML content directly in a Jupyter Notebook

# Use pyLDAvis to create an interactive topic visualization
# - lda: the trained LDA model
# - corpus: the BoW representation of your documents
# - dictionary: the word-to-ID mapping
# - sort_topics=False keeps the original topic order
#  Prepares the topic model and data for interactive visualization 
lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, dictionary, sort_topics=False)

# Save the interactive visualization as an HTML file locally
pyLDAvis.save_html(lda_display, 'lda.html')

# Display the saved HTML file directly in the notebook
display(HTML('lda.html'))

# Circles: 
# Each circle = a topic
# (Size = how dominant the topic is across all documents)

# Bar charts: 
# Top words in a topic, showing both:
    # Frequency
    # Relevance (more informative words)
        # λ = 1 → Sort words purely by frequency within the topic (i.e., show the most common words).
        # λ = 0 → Sort words by how unique they are to the topic (i.e., most distinctive words).
        # λ = 0.6 (default) → A balanced mix of both.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 9
#       1 from IPython.display import display, HTML  # Tools to display HTML content directly in a Jupyter Notebook
#       3 # Use pyLDAvis to create an interactive topic visualization
#       4 # - lda: the trained LDA model
#       5 # - corpus: the BoW representation of your documents
#       6 # - dictionary: the word-to-ID mapping
#       7 # - sort_topics=False keeps the original topic order
#       8 #  Prepares the topic model and data for interactive visualization
# ----> 9 lda_display = pyLDAvis.gensim_models.prepare(lda, corpus, dictionary, sort_topics=False)
#      11 # Save the interactive visualization as an HTML file locally
#      12 pyLDAvis.save_html(lda_display, 'lda.html')
#
# File ~/Library/Python/3.8/lib/python/site-packages/pyLDAvis/gensim_models.py:123, in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#      78 """Transforms the Gensim TopicModel and related corpus and dictionary into
#      79 the data structures needed for the visualization.
#      80
#    (...)
#     120 See `pyLDAvis.prepare` for **kwargs.
#     121 """
#     122 opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 123 return pyLDAvis.prepare(**opts)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pyLDAvis/_prepare.py:432, in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     426 # Quick fix for red bar width bug.  We calculate the
#     427 # term frequencies internally, using the topic term distributions and the
#     428 # topic frequencies, rather than using the user-supplied term frequencies.
#     429 # For a detailed discussion, see: https://github.com/cpsievert/LDAvis/pull/41
#     430 term_frequency = np.sum(term_topic_freq, axis=0)
# --> 432 topic_info = _topic_info(topic_term_dists, topic_proportion,
#     433                          term_frequency, term_topic_freq, vocab, lambda_step, R,
#     434                          n_jobs, start_index)
#     435 token_table = _token_table(topic_info, term_topic_freq, vocab, term_frequency, start_index)
#     436 topic_coordinates = _topic_coordinates(mds, topic_term_dists, topic_proportion, start_index)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pyLDAvis/_prepare.py:243, in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs, start_index)
#     236 # Order the terms for the "default" view by decreasing saliency:
#     237 default_term_info = pd.DataFrame({
#     238     'saliency': saliency,
#     239     'Term': vocab,
#     240     'Freq': term_frequency,
#     241     'Total': term_frequency,
#     242     'Category': 'Default'})
# --> 243 default_term_info = default_term_info.sort_values(
#     244     by='saliency', ascending=False).head(R).drop('saliency', 1)
#     245 # Rounding Freq and Total to integer values to match LDAvis code:
#     246 default_term_info['Freq'] = np.floor(default_term_info['Freq'])
#
# TypeError: drop() takes from 1 to 2 positional arguments but 3 were given

# %%
# Define the two columns we want to extract from the DataFrame:
# - 'Product': the category of the complaint
# - 'lowercase_stopworded_complaints': the cleaned complaint text
col = ['Product','lowercase_stopworded_complaints']

# Create a new DataFrame using only the selected columns
plswork = citigroup_data[col]

# Rename the columns to simpler, more convenient names:
# - 'Product' becomes 'product'    
# - 'lowercase_stopworded_complaints' becomes 'text'
plswork.rename(columns={'Product': 'product', 'lowercase_stopworded_complaints':'text'}, inplace=True)

# Show the first 5 rows of the new DataFrame to verify the structure
plswork.head()
# Out:
#                                                product  \
# 55   Money transfer, virtual currency, or money ser...
# 75                         Checking or savings account
# 80                         Credit card or prepaid card
# 154                        Credit card or prepaid card
# 234  Credit reporting, credit repair services, or o...
#
#                                                   text
# 55   a wire transfer {$23000.00} wa initi onlin , c...
# 75   my father pass away . inform citi hi pass tele...
# 80   back 2021, bought . send back twice within 2 m...
# 154  i platinum card holder macys. gener buy produc...
# 234  i disput unknown inquir compani credit bureau ...

# %%
# LabelEncoder is a library that converts catagorical variables into numeric form (like ID values)
from sklearn.preprocessing import LabelEncoder

# Task: create an instance of a LabelEncoder
le = ???

# each product entry is assigned an id, so that same entries have the same ID number
plswork['product_id']= le.fit_transform(plswork['product'])

# %%
# Task: fill in the blank
# here you can see the unique IDs and how many of them there are
plswork['product_id'].???
# Out:
# product_id
# 4     22092
# 3     16817
# 10    10249
# 1      8967
# 6      7868
# 7      6859
# 0      4450
# 8       844
# 2       765
# 15      737
# 5       267
# 13      214
# 14      206
# 9       102
# 16       34
# 11       34
# 12       22
# Name: count, dtype: int64

# %%
# TF-IDF Vectorizer, with some parameters:
# ngram-range = (1, 1) uses only separated individual words
# stop_word = english removes english stop words from the text
# this is a shorter way compared to the previous section on preprocessing and tf-idf, but there is less that needs to be modified
tfidf = TfidfVectorizer(ngram_range = (1,1),stop_words = 'english')

# %%
# Task: fill in the blank:
# like in the previous tf-idf section, this creates a matrix of tf-idf scores, also of lowercase stopworded complaints
features = tfidf.???(plswork.text).toarray()

# %%
# shows some of the vocab words that the tf-idf identified
tfidf.vocabulary_

# note that the vocab could possibly be cleaned up a bit more
# Out:
# {'wire': 27549,
#  'transfer': 25384,
#  '23000': 521,
#  '00': 0,
#  'wa': 27144,
#  'initi': 13745,
#  'onlin': 17625,
#  'corpor': 6916,
#  'account': 1641,
#  'anoth': 2587,
#  'unsuccess': 26439,
#  'ofac': 17477,
#  'cite': 5515,
#  'reason': 20274,
#  'supervisor': 24079,
#  'citibank': 5550,
#  'department': 8075,
#  'avail': 3390,
#  'inform': 13663,
#  'request': 21203,
#  'ha': 12141,
#  'provided': 19758,
#  'subsequ': 23904,
#  'cancel': 4741,
#  'date': 7608,
#  'fund': 11576,
#  'return': 21513,
#  'abl': 1481,
#  'provid': 19756,
#  'ownership': 18080,
#  'oblig': 17366,
#  'expect': 10335,
#  'know': 14692,
#  'valid': 26763,
#  'withhold': 27589,
#  'urgent': 26614,
#  'requir': 21222,
#  'father': 10644,
#  'pass': 18276,
#  'away': 3445,
#  'citi': 5523,
#  'hi': 12547,
#  'telephon': 24530,
#  'alleg': 2299,
#  'contact': 6687,
#  'steps': 23625,
#  'did': 8342,
#  'fax': 10668,
#  'includ': 13396,
#  'death': 7680,
#  'certificate': 5158,
#  'live': 15196,
#  'trust': 25594,
#  'documents': 8937,
#  'letter': 15018,
#  'intent': 13998,
#  'abov': 1501,
#  'confirm': 6497,
#  'receipt': 20346,
#  'end': 9707,
#  'day': 7626,
#  'receiv': 20352,
#  'instruct': 13942,
#  'close': 5882,
#  'accounts': 1675,
#  'check': 5340,
#  'save': 22066,
#  'sent': 22431,
#  'frozen': 11495,
#  'process': 19506,
#  'withdraw': 27574,
#  'parti': 18243,
#  'despit': 8219,
#  'closed': 5887,
#  'thi': 24853,
#  '240': 528,
#  'charg': 5259,
#  'servic': 22491,
#  'fee': 10738,
#  'month': 16446,
#  'sinc': 22873,
#  'died': 8357,
#  'onc': 17597,
#  'indic': 13542,
#  'taken': 24367,
#  'ani': 2540,
#  'action': 1805,
#  'onli': 17624,
#  'form': 11248,
#  'fals': 10595,
#  'statement': 23544,
#  'continu': 6727,
#  'transact': 25353,
#  'violat': 27014,
#  'cfr': 5187,
#  '405': 799,
#  '2021': 471,
#  'bought': 4282,
#  'send': 22406,
#  'twice': 25684,
#  'cost': 6987,
#  '10': 44,
#  'ship': 22666,
#  'time': 25039,
#  'everi': 10141,
#  'told': 25155,
#  'fault': 10652,
#  'repair': 21011,
#  'new': 16947,
#  'unit': 26199,
#  'second': 22293,
#  'refund': 20679,
#  'money': 16418,
#  'broken': 4407,
#  'file': 10840,
#  'disput': 8745,
#  'gave': 11717,
#  'reasons': 20280,
#  'site': 22901,
#  'forward': 11289,
#  'email': 9580,
#  'commun': 6197,
#  'ask': 3024,
#  'addit': 1866,
#  'limit': 15127,
#  'log': 15277,
#  'make': 15542,
#  'monthli': 16451,
#  'payment': 18380,
#  'merchant': 15915,
#  'respons': 21364,
#  'kind': 14664,
#  'prior': 19431,
#  'notif': 17189,
#  'mail': 15503,
#  'need': 16855,
#  'info': 13653,
#  'track': 25297,
#  'number': 17286,
#  'amplified': 2464,
#  'instance': 13908,
#  'issu': 14383,
#  'phone': 18684,
#  'service': 22492,
#  'sure': 24137,
#  'happen': 12244,
#  'equip': 9916,
#  'quit': 20036,
#  'work': 27663,
#  'dial': 8318,
#  'tone': 25186,
#  'kept': 14639,
#  'notified': 17197,
#  'pattern': 18329,
#  'neglig': 16897,
#  'behalf': 3829,
#  'protect': 19715,
#  'financi': 10884,
#  'customers': 7502,
#  'su': 23849,
#  'mastercard': 15720,
#  'thank': 24681,
#  'platinum': 18843,
#  'card': 4819,
#  'holder': 12648,
#  'macys': 15465,
#  'gener': 11745,
#  'buy': 4604,
#  'product': 19547,
#  'sales': 21986,
#  'purchas': 19867,
#  'cloth': 5914,
#  'item': 14420,
#  'ear': 9267,
#  'necklace': 16849,
#  'deliv': 7983,
#  'separ': 22442,
#  'deliveries': 7990,
#  'home': 12672,
#  'open': 17676,
#  'box': 4303,
#  'maci': 15458,
#  'packag': 18103,
#  'door': 9001,
#  'insid': 13864,
#  'empti': 9673,
#  'case': 4932,
#  'immedi': 13161,
#  'went': 27372,
#  'ahead': 2196,
#  'place': 18801,
#  'order': 17770,
#  'delivered': 7987,
#  'report': 21085,
#  'let': 15014,
#  'assur': 3121,
#  'credit': 7226,
#  'wait': 27164,
#  'week': 27335,
#  'polic': 18963,
#  'assign': 3075,
#  'detect': 8250,
#  'reach': 20182,
#  'deliveri': 7989,
#  'guy': 12135,
#  'neighborhood': 16914,
#  'turn': 25666,
#  'investigation': 14203,
#  'wrong': 27769,
#  'address': 1881,
#  'promis': 19618,
#  'locat': 15250,
#  'knew': 14685,
#  'said': 21964,
#  'later': 14822,
#  'sort': 23221,
#  'relay': 20833,
#  'claim': 5766,
#  'state': 23534,
#  'surprise': 24160,
#  'denial': 8042,
#  'yesterday': 27877,
#  'insist': 13876,
#  'pay': 18339,
#  '1900': 373,
#  'miss': 16269,
#  'items': 14422,
#  'proven': 19749,
#  'house': 12807,
#  'instead': 13919,
#  'left': 14938,
#  'lie': 15080,
#  'mailbox': 15505,
#  'unknown': 26226,
#  'inquir': 13827,
#  'compani': 6228,
#  'bureau': 4531,
#  'refus': 20689,
#  'remov': 20946,
#  'nan': 16738,
#  'fraudul': 11374,
#  'current': 7453,
#  'balanc': 3565,
#  'owing': 18073,
#  'late': 14813,
#  'accurate': 1725,
#  'inaccur': 13309,
#  'directli': 8465,
#  'agenc': 2116,
#  'correct': 6926,
#  'inaccuracy': 13312,
#  'differ': 8367,
#  'fail': 10564,
#  'inaccuraci': 13310,
#  'erron': 9966,
#  'reflect': 20646,
#  'history': 12612,
#  'clear': 5817,
#  'conduct': 6470,
#  'investig': 14195,
#  'fair': 10577,
#  'act': 1801,
#  'accur': 1721,
#  'histori': 12608,
#  'trade': 25311,
#  'line': 15135,
#  'attempt': 3225,
#  'indirectli': 13561,
#  'cra': 7152,
#  'resolution': 21317,
#  'privat': 19446,
#  'right': 21659,
#  'bring': 4387,
#  'litig': 15181,
#  'intend': 13994,
#  'rectifi': 20510,
#  'assist': 3089,
#  'cfpb': 5180,
#  'debt': 7712,
#  'sold': 23147,
#  'settl': 22529,
#  'constantli': 6635,
#  'silent': 22834,
#  'import': 13251,
#  'calls': 4707,
#  'ive': 14459,
#  'tri': 25510,
#  'block': 4117,
#  'doesnt': 8957,
#  'matter': 15753,
#  'numbers': 17291,
#  'someon': 23186,
#  'awhil': 3451,
#  'ago': 2158,
#  'stop': 23699,
#  'dont': 8995,
#  'becaus': 3772,
#  'hard': 12271,
#  'prove': 19747,
#  'daughter': 7619,
#  'anyth': 2645,
#  'noth': 17174,
#  'complaint': 6296,
#  'id': 12979,
#  'submit': 23873,
#  'bank': 3616,
#  'kick': 14653,
#  'road': 21714,
#  'resolve': 21321,
#  'wear': 27302,
#  'easily': 9305,
#  'unauthor': 25820,
#  'deposit': 8110,
#  'person': 18606,
#  'afterward': 2093,
#  'daili': 7559,
#  'withdrawn': 27582,
#  'spoke': 23357,
#  'custom': 7491,
#  'repres': 21127,
#  'holidays': 12660,
#  '30': 636,
#  '60': 1009,
#  'information': 13676,
#  'sever': 22551,
#  'speak': 23266,
#  'rent': 20986,
#  'bills': 4018,
#  'food': 11117,
#  'luck': 15398,
#  'rep': 21007,
#  'hung': 12885,
#  'say': 22080,
#  'longer': 15305,
#  'final': 10870,
#  'author': 3310,
#  'accord': 1616,
#  'rights': 21666,
#  '15': 197,
#  'usc': 26631,
#  '1681': 271,
#  'section': 22311,
#  '602': 1016,
#  'privacy': 19445,
#  '604': 1019,
#  'consum': 6662,
#  'furnish': 11609,
#  'written': 27764,
#  'instructions': 13946,
#  '166b': 269,
#  'creditor': 7250,
#  'treat': 25492,
#  'plan': 18818,
#  'purpose': 19897,
#  'verifi': 26891,
#  'old': 17559,
#  'reject': 20809,
#  'appar': 2708,
#  'paid': 18137,
#  'membership': 15863,
#  'repli': 21063,
#  '180': 354,
#  'cancelled': 4759,
#  'disregard': 8761,
#  'owe': 18070,
#  'aggress': 2147,
#  'collector': 6075,
#  'start': 23517,
#  'overli': 17996,
#  'agent': 2129,
#  '170': 328,
#  'eighti': 9473,
#  'stress': 23770,
#  'wrote': 27783,
#  'ceo': 5132,
#  'citigroup': 5655,
#  'dure': 9213,
#  'ladi': 14746,
#  'maintain': 15531,
#  'visa': 27042,
#  'alway': 2382,
#  'harder': 12275,
#  '350': 709,
#  '94': 1332,
#  'plu': 18900,
#  'equal': 9910,
#  '188': 363,
#  'annualized': 2572,
#  'disputes': 8753,
#  '2000': 440,
#  '2500': 548,
#  'respond': 21356,
#  'dispute': 8747,
#  'false': 10596,
#  'edit': 9399,
#  'video': 26977,
#  'satisfi': 22053,
#  'orders': 17776,
#  'forc': 11151,
#  'befor': 3808,
#  'referenc': 20614,
#  'error': 9971,
#  'look': 15312,
#  'like': 15115,
#  'ids': 13035,
#  'revers': 21549,
#  'temporari': 24566,
#  'warranted': 27226,
#  'far': 10620,
#  'grant': 11987,
#  'perman': 18550,
#  'charge': 5261,
#  'summarize': 24025,
#  'given': 11822,
#  'opportun': 17723,
#  'mention': 15890,
#  'clearli': 5830,
#  'distinguish': 8818,
#  'additionally': 1869,
#  'slip': 23002,
#  'handl': 12211,
#  'thu': 24984,
#  'choic': 5420,
#  'attach': 3196,
#  'coerc': 5991,
#  'complain': 6284,
#  'saw': 22079,
#  'charges': 5281,
#  'run': 21896,
#  'long': 15304,
#  'ny': 17331,
#  'concern': 6415,
#  'year': 27853,
#  'realli': 20237,
#  'outrage': 17909,
#  'hear': 12412,
#  'company': 6237,
#  'list': 15161,
#  'comprehens': 6369,
#  'compil': 6274,
#  'spoken': 23358,
#  'unrespons': 26371,
#  'correspond': 6948,
#  'associ': 3100,
#  'heard': 12413,
#  'anyon': 2642,
#  'secur': 22322,
#  'dept': 8138,
#  'didnt': 8352,
#  'true': 25584,
#  'response': 21369,
#  'updat': 26547,
#  'reopen': 21001,
#  'froze': 11494,
#  'fraud': 11350,
#  'institut': 13929,
#  'suppress': 24124,
#  'appli': 2758,
#  'suppos': 24116,
#  'freez': 11427,
#  'delay': 7922,
#  'someth': 23189,
#  'busi': 4568,
#  'days': 7633,
#  'backanyth': 3486,
#  'write': 27757,
#  '5000': 915,
#  'mistake': 16297,
#  'operations': 17704,
#  'low': 15370,
#  'behold': 3840,
#  'message': 15955,
#  'connect': 6554,
#  'oper': 17695,
#  'messag': 15954,
#  'hour': 12802,
#  'understand': 25983,
#  'whi': 27432,
#  'vendor': 26855,
#  'specif': 23284,
#  'world': 27689,
#  'illeg': 13093,
#  'occasions': 17427,
#  'brought': 4420,
#  'attent': 3237,
#  'absolut': 1524,
#  'veri': 26888,
#  'abet': 1470,
#  'unscrupul': 26399,
#  'individual': 13568,
#  'react': 20193,
#  'requests': 21214,
#  'allow': 2327,
#  'exceed': 10216,
#  'add': 1855,
#  'insult': 13963,
#  'injuri': 13764,
#  'women': 27641,
#  'spent': 23324,
#  'mani': 15615,
#  'dilig': 8412,
#  'perfect': 18518,
#  'help': 12481,
#  'caus': 4987,
#  'extrem': 10485,
#  'anxiety': 2630,
#  'sleepless': 22981,
#  'night': 16995,
#  'ruin': 21882,
#  'notic': 17181,
#  'advertis': 1983,
#  'newspap': 16959,
#  'want': 27200,
#  'young': 27893,
#  'inclus': 13407,
#  'lend': 14986,
#  'practices': 19151,
#  'moral': 16475,
#  'recordings': 20479,
#  'joke': 14543,
#  'hurt': 12906,
#  'favor': 10662,
#  'loyal': 15381,
#  'righted': 21660,
#  'answer': 2595,
#  'apolog': 2685,
#  'credited': 7237,
#  'truli': 25588,
#  'manag': 15583,
#  'use': 26644,
#  'cash': 4939,
#  'accumul': 1716,
#  'redempt': 20544,
#  'point': 18949,
#  'translat': 25413,
#  'dollar': 8970,
#  'redeem': 20537,
#  'points': 18954,
#  'fell': 10763,
#  'deaf': 7665,
#  'ears': 9290,
#  'law': 14850,
#  '1692b': 302,
#  '1692c': 303,
#  '1692d': 304,
#  '1692g': 307,
#  '1666d': 267,
#  'code': 5982,
#  '1692': 299,
#  'states': 23559,
#  '1666b': 265,
#  'mark': 15673,
#  'explain': 10400,
#  'alreadi': 2358,
#  'screenshot': 22209,
#  'purches': 19882,
#  'technic': 24490,
#  'support': 24108,
#  '210': 496,
#  'best': 3926,
#  'complet': 6311,
#  'situat': 22910,
#  'bestbuy': 3933,
#  'store': 23713,
#  'policy': 18974,
#  'accept': 1570,
#  'ad': 1845,
#  'extra': 10476,
#  'today': 25135,
#  'unfortun': 26114,
#  'base': 3686,
#  'listen': 15164,
#  'situation': 22912,
#  'creat': 7191,
#  'refer': 20612,
#  'cashed': 4943,
#  'kindli': 14667,
#  'arrang': 2960,
#  'ridiculous': 21643,
#  'spend': 23318,
#  'finish': 10917,
#  'life': 15090,
#  'offic': 17507,
#  'tire': 25085,
#  'pleas': 18871,
#  'loan': 15237,
#  'citicard': 5604,
#  'cbna': 5021,
#  'realiz': 20232,
#  'confus': 6522,
#  '120': 126,
#  'past': 18299,
#  '609': 1024,
#  'disclosur': 8553,
#  '1681g': 278,
#  'sourc': 23235,
#  'recipients': 20406,
#  'shall': 22594,
#  'subject': 23863,
#  '610': 1032,
#  '1681h': 279,
#  'disclos': 8547,
#  'consumer': 6667,
#  'relat': 20819,
#  'digit': 8396,
#  'social': 23120,
#  'similar': 22846,
#  'identif': 13000,
#  'appropri': 2824,
#  'proof': 19661,
#  'ident': 12996,
#  'requester': 21208,
#  'truncat': 25592,
#  'disclosure': 8554,
#  '611': 1036,
#  'procedur': 19494,
#  'accuraci': 1722,
#  '1681i': 280,
#  'reinvestig': 20800,
#  'contain': 6697,
#  'notifi': 17191,
#  'directly': 8466,
#  'free': 11415,
#  'determin': 8265,
#  'record': 20476,
#  'statu': 23577,
#  'delet': 7938,
#  'paragraph': 18208,
#  'period': 18537,
#  'begin': 3817,
#  'tangibl': 24395,
#  'verifiable': 26892,
#  'definit': 7881,
#  'properli': 19670,
#  '100': 45,
#  'accuracy': 1724,
#  'approv': 2830,
#  'depot': 8124,
#  '500': 914,
#  'driver': 9118,
#  'licens': 15072,
#  'text': 24660,
#  'multipl': 16624,
#  'payoff': 18403,
#  'learn': 14913,
#  'lock': 15255,
#  'releas': 20834,
#  'consult': 6654,
#  'bar': 3662,
#  'regain': 20700,
#  'access': 1579,
#  'alert': 2271,
#  'announc': 2560,
#  'user': 26657,
#  'blocked': 4123,
#  'immediately': 13168,
#  'automat': 3353,
#  '2100': 497,
#  'possibl': 19067,
#  'non': 17062,
#  'hardli': 12277,
#  'tell': 24540,
#  'closur': 5911,
#  'conclud': 6432,
#  'review': 21563,
#  '800': 1220,
#  '1200': 127,
#  'took': 25193,
#  'banks': 3649,
#  'predatori': 19209,
#  'practice': 19149,
#  'especi': 10020,
#  'peopl': 18499,
#  'terms': 24618,
#  'sit': 22900,
#  '46': 859,
#  'max': 15766,
#  'singl': 22884,
#  'regard': 20702,
#  'questions': 20011,
#  'enrol': 9794,
#  'program': 19588,
#  'appear': 2731,
#  'paperless': 18195,
#  'happi': 12253,
#  'function': 11570,
#  'view': 26985,
#  'download': 9044,
#  'doe': 8951,
#  'mobil': 16353,
#  'devices': 8291,
#  'link': 15145,
#  'click': 5846,
#  'received': 20356,
#  'hide': 12554,
#  'recent': 20374,
#  'default': 7833,
#  'chang': 5224,
#  'previou': 19386,
#  'believ': 3857,
#  'clock': 5872,
#  'percent': 18509,
#  'hit': 12615,
#  'defer': 7859,
#  'statements': 23551,
#  'retroact': 21502,
#  'higher': 12564,
#  'rate': 20139,
#  'balances': 3571,
#  '2009': 453,
#  'ban': 3599,
#  'increases': 13487,
#  'got': 11916,
#  'local': 15246,
#  'invalid': 14167,
#  'beneficiari': 3894,
#  'months': 16456,
#  'posit': 19050,
#  'hope': 12732,
#  'care': 4859,
#  'lost': 15345,
#  '28': 583,
#  'member': 15861,
#  'husband': 12912,
#  'die': 8356,
#  'suddenli': 23975,
#  'increas': 13484,
#  'apr': 2848,
#  'satisfaction': 22047,
#  'lower': 15371,
#  '19': 371,
#  'high': 12562,
#  'post': 19072,
#  'leav': 14925,
#  'debit': 7699,
#  'needless': 16865,
#  'hello': 12472,
#  'copi': 6869,
#  'airways': 2235,
#  'unprofession': 26312,
#  'behavior': 3832,
#  'flight': 11021,
#  'larg': 14800,
#  'class': 5791,
#  'upgrad': 26563,
#  'granted': 11989,
#  'ant': 2603,
#  'eh': 9464,
#  'schedul': 22140,
#  'depart': 8068,
#  'travel': 25467,
#  'arriv': 2976,
#  'airport': 2231,
#  'wife': 27495,
#  'minut': 16134,
#  'checkin': 5351,
#  'counter': 7051,
#  'hotel': 12788,
#  'covid': 7129,
#  'times': 25055,
#  'pcr': 18427,
#  'test': 24637,
#  'set': 22522,
#  'expir': 10387,
#  'book': 4232,
#  'airlin': 2224,
#  'quickli': 20023,
#  'fare': 10624,
#  '1600': 236,
#  'dollars': 8971,
#  'upset': 26592,
#  'term': 24603,
#  'condit': 6455,
#  'entitl': 9840,
#  'departur': 8078,
#  'seven': 22546,
#  'offer': 17493,
#  'routing': 21820,
#  'destin': 8230,
#  'respect': 21343,
#  'compens': 6256,
#  'extraordinari': 10479,
#  'circumst': 5490,
#  'avoid': 3425,
#  'measur': 15805,
#  'polit': 18976,
#  'instability': 13897,
#  'safeti': 21958,
#  'weather': 27308,
#  'disruption': 8774,
#  'labour': 14736,
#  'failur': 10571,
#  'air': 2211,
#  'traffic': 25323,
#  'control': 6787,
#  'facilities': 10536,
#  'involuntarili': 14239,
#  'deni': 8039,
#  'board': 4178,
#  'specifi': 23285,
#  'follow': 11104,
#  'reduc': 20578,
#  '50': 913,
#  'rout': 21812,
#  'altern': 2370,
#  'hours': 12804,
#  'distanc': 8807,
#  'great': 12009,
#  'circl': 5478,
#  'method': 15977,
#  'reimburs': 20775,
#  'voluntarili': 27109,
#  'choos': 5426,
#  'ticket': 25004,
#  'price': 19393,
#  'journey': 14550,
#  'compar': 6240,
#  'transport': 25436,
#  'conditions': 6461,
#  'earliest': 9273,
#  'convenience': 6804,
#  'seats': 22286,
#  'elect': 9510,
#  'qualifi': 19959,
#  'meal': 15792,
#  'refresh': 20663,
#  'voucher': 27119,
#  'aircraft': 2217,
#  'telex': 24539,
#  'mails': 15519,
#  'accommod': 1601,
#  'stay': 23599,
#  'becom': 3777,
#  'necessary': 16841,
#  'necessari': 16839,
#  'result': 21437,
#  'cancellation': 4755,
#  'origin': 17807,
#  'departure': 8079,
#  'offered': 17497,
#  'contractu': 6762,
#  'agreement': 2179,
#  'euro': 10107,
#  'came': 4721,
#  'option': 17747,
#  'addition': 1867,
#  'bid': 3974,
#  'unaccept': 25775,
#  'occurr': 17442,
#  'award': 3438,
#  'contract': 6753,
#  'lack': 14740,
#  'ethic': 10085,
#  'await': 3433,
#  'contin': 6722,
#  'think': 24871,
#  'glitch': 11847,
#  'morn': 16489,
#  'advis': 1999,
#  'friend': 11455,
#  'okay': 17553,
#  'verify': 26904,
#  'come': 6120,
#  'verified': 26901,
#  'note': 17161,
#  'offi': 17506,
#  'rever': 21546,
#  'relationship': 20826,
#  'actual': 1834,
#  'criminal': 7305,
#  'way': 27284,
#  'frustrated': 11511,
#  'wont': 27649,
#  'son': 23199,
#  'branch': 4326,
#  'funds': 11589,
#  '81': 1235,
#  'recogn': 20431,
#  'fraudulent': 11376,
#  'unlocked': 26245,
#  'resolved': 21322,
#  'unlock': 26244,
#  'unbeknownst': 25843,
#  'legitimate': 14972,
#  'zip': 27930,
#  'pa': 18091,
#  'resid': 21288,
#  'maryland': 15698,
#  'identifi': 13001,
#  'groceri': 12048,
#  'arizona': 2935,
#  'fruit': 11504,
#  'snacks': 23067,
#  'illegitimate': 13103,
#  'discern': 8532,
#  'years': 27859,
#  'idea': 12986,
#  'listed': 15163,
#  'dissatisfact': 8785,
#  'conversations': 6813,
#  'instant': 13910,
#  'discussed': 8629,
#  'offici': 17515,
#  'remain': 20883,
#  'began': 3813,
#  'delinqu': 7963,
#  'assessed': 3062,
#  'understood': 25995,
#  'frustrations': 11517,
#  'assess': 3060,
#  'removed': 20952,
#  'payments': 18390,
#  'score': 22178,
#  'drop': 9128,
#  '150': 198,
#  'overnight': 18003,
#  '25': 546,
#  'debcredit': 7693,
#  'consequently': 6590,
#  'near': 16820,
#  'unwittingli': 26528,
#  'els': 9568,
#  'repeatedli': 21029,
#  'exist': 10305,
#  'reput': 21189,
#  'harmed': 12292,
#  'escal': 9986,
#  'simpli': 22859,
#  'tortur': 25226,
#  'team': 24477,
#  'power': 19117,
#  'deal': 7666,
#  'complaints': 6300,
#  'type': 25700,
#  'approxim': 2839,
#  'valu': 26776,
#  '900': 1303,
#  'citimobil': 5668,
#  'app': 2702,
#  'legal': 14944,
#  'proceed': 19497,
#  'interven': 14097,
#  'withheld': 27587,
#  'duplic': 9201,
#  'party': 18271,
#  'victim': 26959,
#  'theft': 24746,
#  'remoblock': 20931,
#  'knowledge': 14700,
#  'consent': 6582,
#  '20000': 441,
#  'im': 13126,
#  'ftc': 11530,
#  'compli': 6328,
#  'fcra': 10694,
#  '603': 1018,
#  'mean': 15794,
#  'rule': 21885,
#  'means': 15799,
#  'minimum': 16104,
#  'official': 17516,
#  'federal': 10732,
#  'enforc': 9741,
#  'agency': 2122,
#  'postal': 19075,
#  'inspect': 13886,
#  'govern': 11929,
#  'deem': 7818,
#  'crimin': 7304,
#  'penalti': 18473,
#  'fact': 10543,
#  'languag': 14786,
#  'neglect': 16895,
#  'held': 12469,
#  'impact': 13197,
#  'emotional': 9635,
#  'physic': 18716,
#  'financially': 10888,
#  'pursu': 19909,
#  'remedi': 20900,
#  'research': 21259,
#  'mov': 16560,
#  'feel': 10751,
#  'belong': 3878,
#  'document': 8915,
#  'bear': 3749,
#  'signatur': 22808,
#  'seek': 22343,
#  'game': 11666,
#  'attorney': 3253,
#  'swiftly': 24256,
#  'doubt': 9025,
#  'mysteri': 16702,
#  '605b': 1022,
#  'declin': 7779,
#  'rescind': 21250,
#  'ac': 1554,
#  'half': 12180,
#  'malfunct': 15561,
#  'moment': 16400,
#  ...}

# %%
# task: drop duplicates from both the product and product_id columns
product_id_map = plswork[['product', 'product_id']].???

# dropping duplicates allows you to create a dictionary without repeating values (which would result in values becoming overwritten)
id_to_product = dict(product_id_map[['product_id', 'product']].values)

# %%
# creates labels, which are all the entries in product_id
labels = plswork.product_id

# %%
# divides the dataset into training and testing sets for evaluating performance (3:1 ratio) since we don't have more data for testing
# X is the independent variable, y is the dependent (target variable)
# random_state is a seed for random number generation
X_train, X_test, y_train, y_test = train_test_split(features, labels, random_state=24)

# %%
# shows their "shapes", meaning their dimensions 
# x is the independent variable (samples by features) and y is the dependent variable of labels
# 3 : 1 ratio of train to test
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60395, 27938)
# (20132, 27938)
# (60395,)
# (20132,)

# %%
# below we will be creating classifier models, training them, and comparing their results 
# (identifying products based on features/text)
from sklearn import naive_bayes
from sklearn import metrics
from sklearn import ensemble
from sklearn import linear_model

# creates a multinomial bayes classifier
nb = naive_bayes.MultinomialNB()

# the classifier is trained on the training data
# goal: match the features (text) to the label (product id)
nb.fit(X_train,y_train)

# the classifier is now put to the test
y_pred_nb = nb.predict(X_test)

# evaluate the accuracy of the model
accuracy_nb = metrics.accuracy_score(y_test,y_pred_nb)

# creates a report based on the accuracy and results
cr_nb = metrics.classification_report(y_test,y_pred_nb)

# print out the results
# precision - percentage of how many were correct out of predicted samples (How many predicted positives were correct?)
# recall - percentage of how many were correct out of actual samples (	How many actual positives were caught?)
# f1-core - harmonic mean of precision and recall score
# support - number of actual samples 
# accuracy - overall correct predictions (How many total predictions were correct?)

print("Navie Bayes model accuracy:",accuracy_nb)
print("Navie Bayes classification report:\n",cr_nb)
# Out:
# Navie Bayes model accuracy: 0.33538644943373735
# Navie Bayes classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.01      0.03      1097
#            1       0.76      0.14      0.23      2284
#            2       0.00      0.00      0.00       185
#            3       0.25      0.77      0.38      4153
#            4       0.44      0.51      0.47      5589
#            5       0.00      0.00      0.00        69
#            6       0.78      0.13      0.22      1949
#            7       0.90      0.03      0.06      1683
#            8       0.00      0.00      0.00       219
#            9       0.00      0.00      0.00        17
#           10       0.93      0.03      0.06      2573
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00        59
#           14       0.00      0.00      0.00        48
#           15       0.00      0.00      0.00       190
#           16       0.00      0.00      0.00         4
#
#     accuracy                           0.34     20132
#    macro avg       0.29      0.10      0.08     20132
# weighted avg       0.58      0.34      0.27     20132

# %%
# task: fill in the blanks. many of them follow the same functions as the naive bayes model. their functions are mentioned
# in the comments 

# creates a random forest classifier (a different kind of classifier, we are comparing their accuracies)
rf = ensemble.RandomForestClassifier()

# training the model (using train data)
???

# putting the model to the test (using test data)
y_pred_rf = ???

# calculates the accuracy of the model by comparing the predicted values to the actual results 
# (compare predicted labels to actual labels)
accuracy_rf = ???

# also generates a detailed report on the results
# (based on actual labels and predicted labels)
cr_rf = ???

# print out the results
# columns and rows are the same as the multinomial bayes classifier
print("Random Forest model accuracy:",accuracy_rf)
print("Random Forest classification report:\n",cr_rf)

# the accuracy seems better, possible reasons
# - naive bayes classifier assumes independence of all features
# - random forest uses non linear methods (naive bayes uses linear methods)
# - naive bayes is generally simpler (you can also tell by the run time in this case)
# Out:
# Random Forest model accuracy: 0.39697993244585733
# Random Forest classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.15      0.26      1097
#            1       0.76      0.32      0.45      2284
#            2       0.00      0.00      0.00       185
#            3       0.25      0.78      0.38      4153
#            4       0.58      0.49      0.53      5589
#            5       0.00      0.00      0.00        69
#            6       0.72      0.27      0.39      1949
#            7       0.82      0.18      0.29      1683
#            8       1.00      0.00      0.01       219
#            9       0.00      0.00      0.00        17
#           10       0.94      0.10      0.19      2573
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00         5
#           13       1.00      0.02      0.03        59
#           14       0.00      0.00      0.00        48
#           15       1.00      0.01      0.02       190
#           16       0.00      0.00      0.00         4
#
#     accuracy                           0.40     20132
#    macro avg       0.47      0.14      0.15     20132
# weighted avg       0.63      0.40      0.38     20132

# %%
# task: same as before :)
# logistic regression model (works for categorical data)

lr = linear_model.LogisticRegression()

# train
???

# test
y_pred = ???

# get accuracy
accuracy = metrics.accuracy_score(y_test,y_pred)

# get report
cr = metrics.classification_report(y_test,y_pred_rf)

print("Logistic Regression model accuracy:",accuracy)
print("Logistic Regression classification report:\n",cr)

# logistic vs random forest:
# - logistic assumes a linear relationship between features and the log-odds of the outcome
# - logistic uses a sigmoid function, while random forest makes many decision trees
# - logistic tends to be better for linear relationships, random forest better for nonlinear relationships & data with many features
# Out:
# Logistic Regression model accuracy: 0.41650109278760183
# Logistic Regression classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.16      0.28      1097
#            1       0.75      0.37      0.50      2284
#            2       0.00      0.00      0.00       185
#            3       0.26      0.82      0.39      4153
#            4       0.68      0.46      0.55      5589
#            5       0.00      0.00      0.00        69
#            6       0.65      0.31      0.42      1949
#            7       0.74      0.22      0.34      1683
#            8       0.59      0.17      0.26       219
#            9       0.00      0.00      0.00        17
#           10       0.88      0.13      0.23      2573
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00        59
#           14       0.67      0.04      0.08        48
#           15       0.78      0.09      0.17       190
#           16       0.00      0.00      0.00         4
#
#     accuracy                           0.42     20132
#    macro avg       0.41      0.16      0.19     20132
# weighted avg       0.63      0.42      0.41     20132

# %%
# create a confusion matrix based on the logistic regression model
# plot y_test and y_pred to see where the model is predicting correctly or making mistakes
conf = metrics.confusion_matrix(y_test, y_pred)

# plot labelling
sns.heatmap(conf,annot = True,cmap = "Blues",fmt = 'd')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("Confusion Matrix Logistic Regression\n", size=12)

# optimally, we would want the predicted result to match the actual result - that would mean hotter on the diagonal
# this model is very vaguely on the diagonal
# Out:
# Text(0.5, 1.0, 'Confusion Matrix Logistic Regression\n')

# %%
# Task: create heat maps for the naive bayes model

# %%
# Task: create heat maps for the random forest model
